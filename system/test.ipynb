# %%
import json
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer

# %%
URI = "neo4j+s://7aa78485.databases.neo4j.io"
AUTH = ("neo4j", "iX59KTgWRNyZvmkh3dDBGe0Dwbm-_XQGdP1KCW_m7rs")
driver = GraphDatabase.driver(URI, auth=AUTH)

# %%
with driver.session() as session:
    print("Deleting all nodes and relationships...")
    session.run("MATCH (n) DETACH DELETE n")
    print("Dropping old Vector Index...")
    session.run("DROP INDEX violation_index IF EXISTS")
    print("Database is completely empty and ready for new Schema.")
# Out:
# Deleting all nodes and relationships...
# Dropping old Vector Index...
# Database is completely empty and ready for new Schema.

# %%
model = SentenceTransformer("minhquan6203/paraphrase-vietnamese-law")

# %%
sum([param.numel() for param in model.parameters()])
# Out:
# 278043648

# %%
with open('/home/taidvt/vietnamese-traffic-law-qa/data/processed/ND100_2019_normalized.json', 'r') as f:
    data_100 = json.load(f)

# %%
with open('/home/taidvt/vietnamese-traffic-law-qa/data/processed/ND168_2024_normalized.json', 'r') as f:
    data_168 = json.load(f)

# %%
IMPORT_QUERY = """
// --- 1. Legal Hierarchy ---
// Thêm doc_id để quản lý ID ngắn gọn (VD: ND100, ND123) bên cạnh tên đầy đủ
MERGE (doc:LegalDocument {id: $doc_id}) 
SET doc.name = $doc_name

MERGE (art:Article {name: $art_name})
MERGE (art)-[:PART_OF]->(doc)

MERGE (clause:Clause {name: $clause_name, full_ref: $full_ref})
MERGE (clause)-[:BELONGS_TO]->(art)

// --- 2. Vehicle / Category ---
MERGE (veh:VehicleType {name: $category})

// --- 3. The Violation (Central Node) ---
MERGE (vio:Violation {id: $vid})
SET vio.description = $desc,
    vio.severity = $severity,
    vio.embedding = $embedding,
    // QUAN TRỌNG: Lưu thêm doc_id vào đây để phục vụ lọc nhanh (Pre-filtering)
    vio.doc_id = $doc_id  

MERGE (vio)-[:DEFINED_IN]->(clause)
MERGE (vio)-[:APPLIES_TO]->(veh)

// --- 4. The Fine ---
MERGE (fine:Fine {min: $fine_min, max: $fine_max, currency: $currency})
MERGE (vio)-[:HAS_FINE]->(fine)

// --- 5. Additional Measures ---
FOREACH (measure_text IN $additional_measures | 
    MERGE (sup:SupplementaryPenalty {text: measure_text})
    MERGE (vio)-[:HAS_ADDITIONAL_PENALTY]->(sup)
)
"""

# %%
def import_data(tx, item):
    # Generate Vector Embedding for the description
    # This converts text meaning into numbers for the AI search
    vector = model.encode(item['description']).tolist()
       
    tx.run(IMPORT_QUERY, 
           # Mapping JSON fields to Cypher parameters
           vid=item['id'],
           desc=item['description'],
           severity=item.get('severity', 'Unknown'),
           embedding=vector,
           doc_id='ND100' if "100/2019" in item['legal_basis']['document'] else 'ND168',
           doc_name=item['legal_basis']['document'],
           art_name=item['legal_basis']['article'],
           clause_name=item['legal_basis']['section'],
           full_ref=item['legal_basis']['full_reference'],
           
           category=item['category'],
           
           fine_min=item['penalty']['fine_min'],
           fine_max=item['penalty']['fine_max'],
           currency=item['penalty']['currency'],
           
           additional_measures=item['additional_measures']
    )

# %%
# 4. Run the Import for 100
with driver.session() as session:
    for idx in range(len(data_100['violations'])):
        print("processing violation: ", data_100['violations'][idx]['id'])
        session.execute_write(import_data, data_100['violations'][idx])

print("Knowledge Graph Built Successfully!")
# Out:
# processing violation:  1
# processing violation:  2
# processing violation:  3
# processing violation:  4
# processing violation:  5
# processing violation:  6
# processing violation:  7
# processing violation:  8
# processing violation:  9
# processing violation:  10
# processing violation:  11
# processing violation:  12
# processing violation:  13
# processing violation:  14
# processing violation:  15
# processing violation:  16
# processing violation:  17
# processing violation:  18
# processing violation:  19
# processing violation:  20
# processing violation:  21
# processing violation:  22
# processing violation:  23
# processing violation:  24
# processing violation:  25
# processing violation:  26
# processing violation:  27
# processing violation:  28
# processing violation:  29
# processing violation:  30
# processing violation:  31
# processing violation:  32
# processing violation:  33
# processing violation:  34
# processing violation:  35
# processing violation:  36
# processing violation:  37
# processing violation:  38
# processing violation:  39
# processing violation:  40
# processing violation:  41
# processing violation:  42
# processing violation:  43
# processing violation:  44
# processing violation:  45
# processing violation:  46
# processing violation:  47
# processing violation:  48
# processing violation:  49
# processing violation:  50
# processing violation:  51
# processing violation:  52
# processing violation:  53
# processing violation:  54
# processing violation:  55
# processing violation:  56
# processing violation:  57
# processing violation:  58
# processing violation:  59
# processing violation:  60
# processing violation:  61
# processing violation:  62
# processing violation:  63
# processing violation:  64
# processing violation:  65
# processing violation:  66
# processing violation:  67
# processing violation:  68
# processing violation:  69
# processing violation:  70
# processing violation:  71
# processing violation:  72
# processing violation:  73
# processing violation:  74
# processing violation:  75
# processing violation:  76
# processing violation:  77
# processing violation:  78
# processing violation:  79
# processing violation:  80
# processing violation:  81
# processing violation:  82
# processing violation:  83
# processing violation:  84
# processing violation:  85
# processing violation:  86
# processing violation:  87
# processing violation:  88
# processing violation:  89
# processing violation:  90
# processing violation:  91
# processing violation:  92
# processing violation:  93
# processing violation:  94
# processing violation:  95
# processing violation:  96
# processing violation:  97
# processing violation:  98
# processing violation:  99
# processing violation:  100
# processing violation:  101
# processing violation:  102
# processing violation:  103
# processing violation:  104
# processing violation:  105
# processing violation:  106
# processing violation:  107
# processing violation:  108
# processing violation:  109
# processing violation:  110
# processing violation:  111
# processing violation:  112
# processing violation:  113
# processing violation:  114
# processing violation:  115
# processing violation:  116
# processing violation:  117
# processing violation:  118
# processing violation:  119
# processing violation:  120
# processing violation:  121
# processing violation:  122
# processing violation:  123
# processing violation:  124
# processing violation:  125
# processing violation:  126
# processing violation:  127
# processing violation:  128
# processing violation:  129
# processing violation:  130
# processing violation:  131
# processing violation:  132
# processing violation:  133
# processing violation:  134
# processing violation:  135
# processing violation:  136
# processing violation:  137
# processing violation:  138
# processing violation:  139
# processing violation:  140
# processing violation:  141
# processing violation:  142
# processing violation:  143
# processing violation:  144
# processing violation:  145
# processing violation:  146
# processing violation:  147
# processing violation:  148
# processing violation:  149
# processing violation:  150
# processing violation:  151
# processing violation:  152
# processing violation:  153
# processing violation:  154
# processing violation:  155
# processing violation:  156
# processing violation:  157
# processing violation:  158
# processing violation:  159
# processing violation:  160
# processing violation:  161
# processing violation:  162
# processing violation:  841
# processing violation:  842
# processing violation:  843
# processing violation:  844
# processing violation:  845
# processing violation:  846
# processing violation:  847
# processing violation:  848
# processing violation:  849
# processing violation:  850
# processing violation:  851
# processing violation:  852
# processing violation:  853
# processing violation:  854
# processing violation:  855
# processing violation:  856
# processing violation:  857
# processing violation:  858
# processing violation:  859
# processing violation:  860
# processing violation:  861
# processing violation:  862
# processing violation:  863
# processing violation:  864
# processing violation:  865
# processing violation:  866
# processing violation:  867
# processing violation:  868
# processing violation:  869
# processing violation:  870
# processing violation:  871
# processing violation:  872
# processing violation:  873
# processing violation:  874
# processing violation:  875
# processing violation:  876
# processing violation:  877
# processing violation:  878
# processing violation:  879
# processing violation:  880
# processing violation:  881
# processing violation:  882
# processing violation:  883
# processing violation:  884
# processing violation:  885
# processing violation:  886
# processing violation:  887
# processing violation:  888
# processing violation:  889
# processing violation:  890
# processing violation:  891
# processing violation:  892
# processing violation:  893
# processing violation:  894
# processing violation:  895
# processing violation:  896
# processing violation:  897
# processing violation:  898
# processing violation:  899
# processing violation:  900
# processing violation:  901
# processing violation:  902
# processing violation:  903
# processing violation:  904
# processing violation:  905
# processing violation:  906
# processing violation:  907
# processing violation:  908
# processing violation:  909
# processing violation:  910
# processing violation:  911
# processing violation:  912
# processing violation:  913
# processing violation:  914
# processing violation:  915
# processing violation:  916
# processing violation:  917
# processing violation:  918
# processing violation:  919
# processing violation:  920
# processing violation:  921
# processing violation:  922
# processing violation:  923
# processing violation:  924
# processing violation:  925
# processing violation:  926
# processing violation:  927
# processing violation:  928
# processing violation:  929
# processing violation:  930
# processing violation:  931
# processing violation:  932
# processing violation:  933
# processing violation:  934
# processing violation:  935
# processing violation:  936
# processing violation:  937
# processing violation:  938
# processing violation:  939
# processing violation:  940
# processing violation:  941
# processing violation:  942
# processing violation:  943
# processing violation:  944
# processing violation:  945
# processing violation:  946
# processing violation:  947
# processing violation:  948
# processing violation:  949
# processing violation:  950
# processing violation:  951
# processing violation:  952
# processing violation:  953
# processing violation:  954
# processing violation:  955
# processing violation:  956
# processing violation:  957
# processing violation:  958
# processing violation:  959
# processing violation:  960
# processing violation:  961
# processing violation:  962
# processing violation:  963
# processing violation:  964
# processing violation:  965
# processing violation:  966
# processing violation:  967
# processing violation:  968
# processing violation:  969
# processing violation:  970
# processing violation:  971
# processing violation:  972
# processing violation:  973
# processing violation:  974
# processing violation:  975
# processing violation:  976
# processing violation:  977
# processing violation:  978
# processing violation:  979
# processing violation:  980
# processing violation:  981
# processing violation:  982
# processing violation:  983
# processing violation:  984
# processing violation:  985
# processing violation:  986
# processing violation:  987
# processing violation:  988
# processing violation:  989
# processing violation:  990
# processing violation:  991
# processing violation:  992
# processing violation:  993
# processing violation:  994
# processing violation:  995
# processing violation:  996
# processing violation:  997
# processing violation:  998
# processing violation:  999
# processing violation:  1000
# processing violation:  1001
# processing violation:  1002
# processing violation:  1003
# processing violation:  1004
# processing violation:  1005
# processing violation:  1006
# processing violation:  1007
# processing violation:  1008
# processing violation:  1315
# processing violation:  1316
# processing violation:  1317
# processing violation:  1318
# processing violation:  1319
# processing violation:  1320
# processing violation:  1321
# processing violation:  1322
# processing violation:  1323
# processing violation:  1324
# processing violation:  1325
# processing violation:  1326
# processing violation:  1327
# processing violation:  1328
# processing violation:  1329
# processing violation:  1330
# processing violation:  1331
# processing violation:  1332
# processing violation:  1333
# processing violation:  1334
# processing violation:  1335
# processing violation:  1336
# processing violation:  1337
# processing violation:  1338
# processing violation:  1339
# processing violation:  1340
# processing violation:  1341
# processing violation:  1342
# processing violation:  1343
# processing violation:  1344
# processing violation:  1345
# processing violation:  1346
# processing violation:  1347
# processing violation:  1348
# processing violation:  1349
# processing violation:  1350
# processing violation:  1351
# processing violation:  1352
# processing violation:  1353
# processing violation:  1354
# processing violation:  1355
# processing violation:  1356
# processing violation:  1357
# processing violation:  1358
# processing violation:  1359
# processing violation:  1360
# processing violation:  1361
# processing violation:  1362
# processing violation:  1363
# processing violation:  1364
# processing violation:  1365
# processing violation:  1366
# processing violation:  1367
# processing violation:  1368
# processing violation:  1369
# processing violation:  1370
# processing violation:  1371
# processing violation:  1372
# processing violation:  1373
# processing violation:  1374
# processing violation:  1375
# Knowledge Graph Built Successfully!

# %% [markdown]
# # extract all legal reference

# %%
import re
from typing import List, Dict

def extract_all_legal_references(text: str) -> List[Dict[str, str]]:
    """
    Extract all legal references with metadata.
    Returns list of dicts with 'type', 'point', and 'clause' fields.
    """
    results = []
    
    # Pattern for "điểm X, điểm Y khoản Z"
    pattern_with_points = r'((?:điểm\s+[a-zđ](?:,\s*)?)+)\s*khoản\s+(\d+)'
    
    # Track positions of already-matched khoản references
    matched_positions = set()
    
    # First pass: find all điểm + khoản combinations
    for match in re.finditer(pattern_with_points, text, re.IGNORECASE):
        points_str = match.group(1)
        clause_num = match.group(2)
        
        # Track this khoản's position
        matched_positions.add(match.start(2))
        
        # Extract individual points
        points = re.findall(r'điểm\s+([a-zđ])', points_str, re.IGNORECASE)
        
        for point in points:
            results.append({
                'type': 'point_clause',
                'point': point,
                'clause': clause_num,
                'formatted': f"điểm {point}, khoản {clause_num}"
            })
    
    # Second pass: find standalone khoản references
    for match in re.finditer(r'khoản\s+(\d+)', text, re.IGNORECASE):
        if match.start() not in matched_positions:
            # Check if there's a điểm within 50 characters before this khoản
            context_start = max(0, match.start() - 50)
            context = text[context_start:match.start()]
            
            if not re.search(r'điểm\s+[a-zđ]', context, re.IGNORECASE):
                clause_num = match.group(1)
                results.append({
                    'type': 'clause_only',
                    'point': None,
                    'clause': clause_num,
                    'formatted': f"khoản {clause_num}"
                })
    
    return results


for idx in range(len(data_168['violations'])):
    additional_measures = data_168['violations'][idx]['additional_measures']
    legal_basis = data_168['violations'][idx]['legal_basis']
    article = legal_basis['article']
    section = legal_basis['section']
    point = legal_basis['point']
    norm_additional_measures = []
    for measure in additional_measures:
        # Extract legal references using the new function
        measure_refs = extract_all_legal_references(measure['details'])
        
        # Check if this violation's legal basis matches any extracted reference
        match_found = False
        matched_ref = None
        
        for ref in measure_refs:
            # Case 1: Match point + clause (e.g., "Điểm h, Khoản 3")
            if ref['type'] == 'point_clause' and point and section:
                # Construct expected format: "điểm x, khoản y"
                expected = f"{point}, {section}".lower()
                if ref['formatted'].lower() == expected:
                    match_found = True
                    matched_ref = expected

                    break
            
            # Case 2: Match clause only (e.g., "Khoản 12") when no point specified
            elif ref['type'] == 'clause_only' and not point:
                if ref['formatted'].lower() == section.lower():
                    match_found = True
                    matched_ref = section
                    break
        
        if match_found:
            if measure.get('points'):
                norm_additional_measures.append(f"{measure['type']}: {measure['points']}")
            elif measure.get('duration'):
                norm_additional_measures.append(f"{measure['type']}: {measure['duration']}")
            else:
                norm_additional_measures.append(f"{measure['type']}")
    data_168['violations'][idx]['id'] = data_168['violations'][idx]['id']+1375
    data_168['violations'][idx]['additional_measures'] = norm_additional_measures

# %%
with open('./data/processed/violations_168_normalized.json', 'w') as f:
    json.dump(data_168, f, indent=4, ensure_ascii=False)

# %%
# 4. Run the Import for 168
with driver.session() as session:
    for idx in range(len(data_168['violations'])):
        print("processing violation: ", data_168['violations'][idx]['id'])
        session.execute_write(import_data, data_168['violations'][idx])

print("Knowledge Graph Built Successfully!")
# Out:
# processing violation:  1376
# processing violation:  1377
# processing violation:  1378
# processing violation:  1379
# processing violation:  1380
# processing violation:  1381
# processing violation:  1382
# processing violation:  1383
# processing violation:  1384
# processing violation:  1385
# processing violation:  1386
# processing violation:  1387
# processing violation:  1388
# processing violation:  1389
# processing violation:  1390
# processing violation:  1391
# processing violation:  1392
# processing violation:  1393
# processing violation:  1394
# processing violation:  1395
# processing violation:  1396
# processing violation:  1397
# processing violation:  1398
# processing violation:  1399
# processing violation:  1400
# processing violation:  1401
# processing violation:  1402
# processing violation:  1403
# processing violation:  1404
# processing violation:  1405
# processing violation:  1406
# processing violation:  1407
# processing violation:  1408
# processing violation:  1409
# processing violation:  1410
# processing violation:  1411
# processing violation:  1412
# processing violation:  1413
# processing violation:  1414
# processing violation:  1415
# processing violation:  1416
# processing violation:  1417
# processing violation:  1418
# processing violation:  1419
# processing violation:  1420
# processing violation:  1421
# processing violation:  1422
# processing violation:  1423
# processing violation:  1424
# processing violation:  1425
# processing violation:  1426
# processing violation:  1427
# processing violation:  1428
# processing violation:  1429
# processing violation:  1430
# processing violation:  1431
# processing violation:  1432
# processing violation:  1433
# processing violation:  1434
# processing violation:  1435
# processing violation:  1436
# processing violation:  1437
# processing violation:  1438
# processing violation:  1439
# processing violation:  1440
# processing violation:  1441
# processing violation:  1442
# processing violation:  1443
# processing violation:  1444
# processing violation:  1445
# processing violation:  1446
# processing violation:  1447
# processing violation:  1448
# processing violation:  1449
# processing violation:  1450
# processing violation:  1451
# processing violation:  1452
# processing violation:  1453
# processing violation:  1454
# processing violation:  1455
# processing violation:  1456
# processing violation:  1457
# processing violation:  1458
# processing violation:  1459
# processing violation:  1460
# processing violation:  1461
# processing violation:  1462
# processing violation:  1463
# processing violation:  1464
# processing violation:  1465
# processing violation:  2076
# processing violation:  2077
# processing violation:  2078
# processing violation:  2079
# processing violation:  2080
# processing violation:  2081
# processing violation:  2082
# processing violation:  2083
# processing violation:  2084
# processing violation:  2085
# processing violation:  2086
# processing violation:  2087
# processing violation:  2088
# processing violation:  2089
# processing violation:  2090
# processing violation:  2091
# processing violation:  2092
# processing violation:  2093
# processing violation:  2094
# processing violation:  2095
# processing violation:  2096
# processing violation:  2097
# processing violation:  2098
# processing violation:  2099
# processing violation:  2100
# processing violation:  2101
# processing violation:  2102
# processing violation:  2103
# processing violation:  2104
# processing violation:  2105
# processing violation:  2106
# processing violation:  2107
# processing violation:  2108
# processing violation:  2109
# processing violation:  2110
# processing violation:  2111
# processing violation:  2112
# processing violation:  2113
# processing violation:  2114
# processing violation:  2115
# processing violation:  2116
# processing violation:  2117
# processing violation:  2118
# processing violation:  2119
# processing violation:  2120
# processing violation:  2121
# processing violation:  2122
# processing violation:  2123
# processing violation:  2124
# processing violation:  2125
# processing violation:  2126
# processing violation:  2127
# processing violation:  2128
# processing violation:  2129
# processing violation:  2130
# processing violation:  2131
# processing violation:  2132
# processing violation:  2133
# processing violation:  2134
# processing violation:  2135
# processing violation:  2136
# processing violation:  2137
# processing violation:  2138
# processing violation:  2139
# processing violation:  2140
# processing violation:  2141
# processing violation:  2142
# processing violation:  2143
# processing violation:  2144
# processing violation:  2145
# processing violation:  2146
# processing violation:  2147
# processing violation:  2148
# processing violation:  2149
# processing violation:  2150
# processing violation:  2151
# processing violation:  2152
# processing violation:  2153
# processing violation:  2154
# processing violation:  2155
# processing violation:  2156
# processing violation:  2157
# processing violation:  2158
# processing violation:  2159
# processing violation:  2160
# processing violation:  2161
# processing violation:  2162
# processing violation:  2163
# processing violation:  2164
# processing violation:  2165
# processing violation:  2166
# processing violation:  2167
# processing violation:  2168
# processing violation:  2169
# processing violation:  2170
# processing violation:  2171
# processing violation:  2172
# processing violation:  2173
# processing violation:  2174
# processing violation:  2175
# processing violation:  2176
# processing violation:  2177
# processing violation:  2178
# processing violation:  2179
# processing violation:  2180
# processing violation:  2181
# processing violation:  2182
# Knowledge Graph Built Successfully!

# %%
len(data_168['violations'])
# Out:
# 807

# %% [markdown]
# # Query

# %%
def search_traffic_law(user_question, top_k=3):
    driver = GraphDatabase.driver(URI, auth=AUTH)
    
    # Step A: Convert User Question to Vector
    question_embedding = model.encode(user_question).tolist()
    
    # Step B: The Cypher Query
    # This is a "Hybrid" query:
    # 1. It uses Vector Search to find the closest Violation node.
    # 2. It traverses the graph to find the connected Fine, Article, and Vehicle.
    query = """
    // 1. Find top k similar violations using the Vector Index
    CALL db.index.vector.queryNodes('violation_index', $k, $embedding)
    YIELD node AS violation, score
    
    // 2. Traverse the Graph to get context (The "Relational" part)
    MATCH (violation)-[:HAS_FINE]->(fine:Fine)
    MATCH (violation)-[:DEFINED_IN]->(clause:Clause)-[:BELONGS_TO]->(article:Article)
    MATCH (violation)-[:APPLIES_TO]->(vehicle:VehicleType)
    
    // 3. Optional: Get additional penalties if they exist
    OPTIONAL MATCH (violation)-[:HAS_ADDITIONAL_PENALTY]->(sup:SupplementaryPenalty)
    
    // 4. Return structured data
    RETURN 
        violation.description AS description,
        vehicle.name AS vehicle,
        fine.min AS min_fine,
        fine.max AS max_fine,
        article.name AS article,
        clause.name AS clause,
        collect(sup.text) AS additional_penalties,
        score
    """
    
    results = []
    with driver.session() as session:
        result = session.run(query, k=top_k, embedding=question_embedding)
        
        for record in result:
            results.append({
                "score": record["score"], # How confident the AI is (0 to 1)
                "description": record["description"],
                "vehicle": record["vehicle"],
                "fine": f"{record['min_fine']:,} - {record['max_fine']:,} VNĐ",
                "law": f"{record['article']}, {record['clause']}",
                "extra": record["additional_penalties"]
            })
            print(record['description'])
            
    driver.close()
    return results

# %%
# 2. Get the exact dimension of your model
# (Crucial: If this number doesn't match the index, search will fail later)
embedding_dimension = model.get_sentence_embedding_dimension()
print(f"Model Dimension: {embedding_dimension}")
# Out:
# Model Dimension: 768

# %%
# 3. Create the Index
def create_vector_index():
    driver = GraphDatabase.driver(URI, auth=AUTH)
    query = """
    CREATE VECTOR INDEX violation_index IF NOT EXISTS
    FOR (v:Violation)
    ON (v.embedding)
    OPTIONS {indexConfig: {
      `vector.dimensions`: $dim,
      `vector.similarity_function`: 'cosine'
    }}
    """
    
    try:
        with driver.session() as session:
            session.run(query, dim=embedding_dimension)
            print("✅ Success: Vector Index 'violation_index' created.")
    except Exception as e:
        print(f"❌ Error: {e}")
    finally:
        driver.close()

# %%
create_vector_index()
# Out:
# ✅ Success: Vector Index 'violation_index' created.

# %%
# --- TEST THE SYSTEM ---
question = "Xe máy vượt đèn xanh phạt bao nhiêu"
print(f"User asks: '{question}'\n")

answers = search_traffic_law(question, 5)

if answers:
    for i, answer in enumerate(answers):
        top_match = answer
        print(f"--- Match {i+1} (Confidence: {top_match['score']:.2f}) ---")
        print(f"Hành vi: {top_match['description']}")
        print(f"Phương tiện: {top_match['vehicle']}")
        print(f"Mức phạt: {top_match['fine']}")
        print(f"Căn cứ pháp lý: {top_match['law']}")
        if top_match['extra']:
            print(f"Hình thức bổ sung: {', '.join(top_match['extra'])}")
else:
    print("Không tìm thấy dữ liệu phù hợp.")
# Out:
# User asks: 'Xe máy vượt đèn xanh phạt bao nhiêu'
#
# Không chấp hành hiệu lệnh hoặc chỉ dẫn của đèn tín hiệu, biển báo hiệu, vạch kẻ đường
# Không chấp hành hiệu lệnh hoặc chỉ dẫn của đèn tín hiệu, biển báo hiệu, vạch kẻ đường
# Đ) Không chấp hành hiệu lệnh của đèn tín hiệu giao thông.
# Không chấp hành hiệu lệnh của đèn tín hiệu giao thông.
# Thực hiện hành vi quy định tại khoản 4 Điều này buộc phải tháo dỡ các vật che khuất biển báo hiệu đường bộ, đèn tín hiệu giao thông
# --- Match 1 (Confidence: 0.95) ---
# Hành vi: Không chấp hành hiệu lệnh hoặc chỉ dẫn của đèn tín hiệu, biển báo hiệu, vạch kẻ đường
# Phương tiện: Xe thô sơ
# Mức phạt: 60,000 - 100,000 VNĐ
# Căn cứ pháp lý: Điều 10, Khoản 1
# --- Match 2 (Confidence: 0.95) ---
# Hành vi: Không chấp hành hiệu lệnh hoặc chỉ dẫn của đèn tín hiệu, biển báo hiệu, vạch kẻ đường
# Phương tiện: Người đi bộ
# Mức phạt: 60,000 - 100,000 VNĐ
# Căn cứ pháp lý: Điều 9, Khoản 1
# --- Match 3 (Confidence: 0.95) ---
# Hành vi: Đ) Không chấp hành hiệu lệnh của đèn tín hiệu giao thông.
# Phương tiện: Xe mô tô, xe máy
# Mức phạt: 1,000,000 - 2,000,000 VNĐ
# Căn cứ pháp lý: Điều 7, Khoản 5
# --- Match 4 (Confidence: 0.95) ---
# Hành vi: Không chấp hành hiệu lệnh của đèn tín hiệu giao thông.
# Phương tiện: Xe thô sơ
# Mức phạt: 100,000 - 200,000 VNĐ
# Căn cứ pháp lý: Điều 8, Khoản 2
# --- Match 5 (Confidence: 0.95) ---
# Hành vi: Thực hiện hành vi quy định tại khoản 4 Điều này buộc phải tháo dỡ các vật che khuất biển báo hiệu đường bộ, đèn tín hiệu giao thông
# Phương tiện: Vi phạm tín hiệu giao thông
# Mức phạt: 6,000,000 - 8,000,000 VNĐ
# Căn cứ pháp lý: Điều 11, Khoản 10
# Hình thức bổ sung: Tước quyền sử dụng giấy phép lái xe từ 01 đến 03 tháng

# %%
# 4. Create Fulltext Index for BM25/Keyword Search
def create_fulltext_index():
    driver = GraphDatabase.driver(URI, auth=AUTH)
    
    # Drop existing index if it exists
    drop_query = """
    DROP INDEX violation_text_index IF EXISTS
    """
    
    # Create fulltext index on Violation.description
    create_query = """
    CREATE FULLTEXT INDEX violation_text_index IF NOT EXISTS
    FOR (v:Violation)
    ON EACH [v.description]
    """
    
    try:
        with driver.session() as session:
            session.run(drop_query)
            session.run(create_query)
            print("✅ Success: Fulltext Index 'violation_text_index' created.")
    except Exception as e:
        print(f"❌ Error: {e}")
    finally:
        driver.close()

create_fulltext_index()
# Out:
# ✅ Success: Fulltext Index 'violation_text_index' created.

# %%
from scripts.category_detector import VehicleCategoryDetector
detector = VehicleCategoryDetector()

# %%
vehicle_patterns = [keywords for keywords in detector.vehicle_patterns] 
business_patterns = [keywords for keywords in detector.business_patterns]
fallback_patterns = [keywords for keywords in detector.fallback_categories]

# %%
from google import genai
# Mocking the LLM Extraction function (Replace with actual API call)
def extract_entities_with_llm(query, vehicle_patterns, business_patterns, fallback_patterns):
    SYSTEM_PROMPT = f"""
    You are a Vietnamese traffic law assistant. Your task is to analyze user queries and determine if they are asking about ILLEGAL actions (traffic violations) or LEGAL actions.

    **Step 1: Determine if the query is about an illegal action (violation)**
    - ILLEGAL actions include: vượt đèn đỏ (running red light), nồng độ cồn (alcohol violation), không đội mũ bảo hiểm (no helmet), quá tốc độ (speeding), lấn làn (lane violation), không có giấy phép (no license), etc.
    - LEGAL actions include: vượt đèn xanh (going through green light), đi đúng làn (proper lane usage), đội mũ bảo hiểm (wearing helmet), đi đúng tốc độ (proper speed), etc.

    **Step 2: Extract entities in JSON format**
    If the query is about an ILLEGAL action (violation):
    1. "category": Map to one of these exact values (Following the priority order, if it includes in the higher priority, return that value):
      1.1. {vehicle_patterns}. 
      1.2. {business_patterns}.
      1.3. {fallback_patterns}.
      1.4. If not specified, return null.
    2. "intent": The complete violation expressed as an AFFIRMATIVE SENTENCE (statement), not as a question. Extract the violation action WITH ALL RELEVANT CONTEXTUAL DETAILS and convert it to a declarative form. PRESERVE important context such as:
       - Location/place (e.g., "trong khu dân cư", "trên đường cao tốc", "tại nơi có biển báo")
       - Conditions (e.g., "vào ban đêm", "trong mưa", "khi có người đi bộ")
       - Circumstances (e.g., "gây tai nạn", "không có người giám sát", "trong tình trạng say")
       - Specific details that affect the severity or nature of the violation
       - add the comma between verbs.
       
       Examples: "vượt đèn đỏ", "nồng độ cồn", "không đội mũ bảo hiểm", "quay đầu xe trái quy định trong khu dân cư", "vượt tốc độ trên đường cao tốc"

    If the query is about a LEGAL action (NOT a violation):
    - Return: {{"category": null, "intent": null}}

    **Examples:**

    User Query: "Đi xe con mà vượt đèn đỏ thì sao?"
    Reasoning: Vượt đèn đỏ is ILLEGAL - convert question to affirmative statement
    Output: {{"category": "Xe ô tô", "intent": "đi xe con vượt đèn đỏ"}}

    User Query: "Mức phạt nồng độ cồn?"
    Reasoning: Nồng độ cồn is ILLEGAL - convert question to affirmative statement
    Output: {{"category": null, "intent": "nồng độ cồn"}}

    User Query: "Xe con vượt đèn xanh phạt bao nhiêu?"
    Reasoning: Vượt đèn xanh is LEGAL, not a violation
    Output: {{"category": null, "intent": null}}

    User Query: "Xe máy đội mũ bảo hiểm có bị phạt không?"
    Reasoning: Đội mũ bảo hiểm is LEGAL, not a violation
    Output: {{"category": null, "intent": null}}

    User Query: "Không đội mũ bảo hiểm bị phạt như thế nào?"
    Reasoning: Không đội mũ bảo hiểm is ILLEGAL - convert question to affirmative statement
    Output: {{"category": null, "intent": "không đội mũ bảo hiểm"}}

    User Query: "Có bị phạt khi vượt đèn đỏ không?"
    Reasoning: Vượt đèn đỏ is ILLEGAL - convert question to affirmative statement
    Output: {{"category": null, "intent": "vượt đèn đỏ"}}

    User Query: "Quay đầu xe trái quy định trong khu dân cư phạt bao nhiêu?"
    Reasoning: Quay đầu xe trái quy định is ILLEGAL - PRESERVE location context "trong khu dân cư"
    Output: {{"category": null, "intent": "quay đầu xe trái quy định trong khu dân cư"}}

    User Query: "Xe máy vượt tốc độ trên đường cao tốc bị phạt gì?"
    Reasoning: Vượt tốc độ is ILLEGAL - PRESERVE location context "trên đường cao tốc"
    Output: {{"category": "Xe mô tô, xe gắn máy", "intent": "xe máy vượt tốc độ trên đường cao tốc"}}

    Analyze the query and return only the JSON output.
    """
    client = genai.Client(api_key="AIzaSyDv3cuC2X3_e2_2Yyejvk5cscNA_6XVnfI")
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        config= genai.types.GenerateContentConfig(
            system_instruction=SYSTEM_PROMPT,
            response_mime_type="application/json",
        ),
        contents=query
    )
    extraction = json.loads(response.text)

        
    return {"category": extraction['category'], "intent": extraction['intent']}

def search_with_filter(user_query):
    # A. Extract Entities (The "Symbolic" Filter)
    extraction = extract_entities_with_llm(user_query, vehicle_patterns, business_patterns, fallback_patterns)
    target_category = extraction['category']
    query_intent = extraction['intent']

    if query_intent == None:
        print("Không biết.")
        return []
    # B. Embed the Query (The "Neuro" Search)
    # Note: We add "query:" prefix for the E5 model
    vector = model.encode(f"query: {query_intent}").tolist()
    
    print(f"🔍 Filter: {target_category} | Search: {user_query} | Intent: {query_intent}")

    # C. Dynamic Cypher Query
    # We construct the query based on whether a vehicle was found
    if target_category:
        # OPTION 1: Strict Filtering (Best for accuracy)
        cypher_query = """
        CALL db.index.vector.queryNodes('violation_index', 50, $embedding)
        YIELD node AS violation, score
        
        // --- THE FILTERING MAGIC HAPPENS HERE ---
        MATCH (violation)-[:APPLIES_TO]->(v:VehicleType)
        WHERE v.name CONTAINS $category_filter  // Only keep matching vehicles
        
        // Retrieve details
        MATCH (violation)-[:HAS_FINE]->(fine:Fine)
        MATCH (violation)-[:DEFINED_IN]->(clause:Clause)-[:BELONGS_TO]->(article:Article)
        
        RETURN violation.description, v.name as vehicle, fine.min, fine.max, clause.full_ref, score
        ORDER BY score DESC LIMIT 5
        """
    else:
        # OPTION 2: No Filter (Search everything)
        cypher_query = """
        CALL db.index.vector.queryNodes('violation_index', 50, $embedding)
        YIELD node AS violation, score
        
        MATCH (violation)-[:APPLIES_TO]->(v:VehicleType)
        MATCH (violation)-[:HAS_FINE]->(fine:Fine)
        MATCH (violation)-[:DEFINED_IN]->(clause:Clause)-[:BELONGS_TO]->(article:Article)
        
        RETURN violation.description, v.name as vehicle, fine.min, fine.max, clause.full_ref, score
        ORDER BY score DESC LIMIT 5
        """

    # Run the query with appropriate parameters
    with driver.session() as session:
        if target_category:
            # Pass category_filter only when it's used in the query
            result = session.run(cypher_query, 
                                 embedding=vector, 
                                 category_filter=target_category)
        else:
            # Don't pass category_filter when not needed
            result = session.run(cypher_query, embedding=vector)
        results = [record.data() for record in result]
    
    # Fallback: if no results and we had a category filter, try without it
    if len(results) == 0 and target_category:
        cypher_query = """
        CALL db.index.vector.queryNodes('violation_index', 50, $embedding)
        YIELD node AS violation, score
        
        MATCH (violation)-[:APPLIES_TO]->(v:VehicleType)
        MATCH (violation)-[:HAS_FINE]->(fine:Fine)
        MATCH (violation)-[:DEFINED_IN]->(clause:Clause)-[:BELONGS_TO]->(article:Article)
        
        RETURN violation.description, v.name as vehicle, fine.min, fine.max, clause.full_ref, score
        ORDER BY score DESC LIMIT 5
        """
        with driver.session() as session:
            result = session.run(cypher_query, embedding=vector)
            results = [record.data() for record in result]
    
    return results

# %%
# --- TEST ---
# Case 1: Specific Vehicle
results = search_with_filter("Xe con vượt đèn đỏ phạt bao nhiêu?")
for result in results:
    print(result)
# Result: Will ONLY return Car violations.

# Case 2: General Question
results = search_with_filter("Vượt đèn đỏ phạt bao nhiêu?")
for result in results:
    print(result)
# Result: Will return Car, Motorbike, and Bicycle violations mixed.
# Out:
# 🔍 Filter: Xe ô tô | Search: Xe con vượt đèn đỏ phạt bao nhiêu?
# {'violation.description': 'Không chấp hành hiệu lệnh, hướng dẫn của người điều khiển giao thông hoặc người kiểm soát giao thông', 'vehicle': 'Xe ô tô', 'fine.min': 3000000, 'fine.max': 5000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 5, Khoản 5', 'score': 0.9561658501625061}
# {'violation.description': 'Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông b) Điều khiển xe lạng lách, đánh võng', 'vehicle': 'Xe ô tô', 'fine.min': 10000000, 'fine.max': 12000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 5, Khoản 7', 'score': 0.9443382024765015}
# {'violation.description': 'Vi phạm quy định về kinh doanh, điều kiện kinh doanh vận tải bằng xe ô tô để xảy ra tai nạn giao thông gây hậu quả từ mức nghiêm trọng trở lên', 'vehicle': 'Xe ô tô', 'fine.min': 7000000, 'fine.max': 10000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 28, Khoản 7', 'score': 0.9290562272071838}
# {'violation.description': 'Dừng xe, đỗ xe, quay đầu xe, lùi xe, tránh xe, vượt xe, chuyển hướng, chuyển làn đường không đúng quy định gây tai nạn giao thông', 'vehicle': 'Xe ô tô', 'fine.min': 10000000, 'fine.max': 12000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 5, Khoản 7', 'score': 0.9267510175704956}
# {'violation.description': 'Không chú ý quan sát, điều khiển xe chạy quá tốc độ quy định gây tai nạn giao thông', 'vehicle': 'Xe ô tô', 'fine.min': 10000000, 'fine.max': 12000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 5, Khoản 7', 'score': 0.9245838522911072}
# 🔍 Filter: None | Search: Vượt đèn đỏ phạt bao nhiêu?
# {'violation.description': 'Không chấp hành hiệu lệnh hoặc chỉ dẫn của đèn tín hiệu, biển báo hiệu, vạch kẻ đường', 'vehicle': 'Người đi bộ', 'fine.min': 60000, 'fine.max': 100000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 9, Khoản 1', 'score': 0.9604647159576416}
# {'violation.description': 'Không chấp hành hiệu lệnh hoặc chỉ dẫn của đèn tín hiệu, biển báo hiệu, vạch kẻ đường', 'vehicle': 'Xe thô sơ', 'fine.min': 60000, 'fine.max': 100000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 10, Khoản 1', 'score': 0.9604647159576416}
# {'violation.description': 'Không chấp hành hiệu lệnh của người điều khiển giao thông', 'vehicle': 'Vi phạm tín hiệu giao thông', 'fine.min': 4000000, 'fine.max': 5000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 4, Khoản 1', 'score': 0.9497003555297852}
# {'violation.description': 'Đ) Không chấp hành hiệu lệnh của đèn tín hiệu giao thông.', 'vehicle': 'Xe mô tô, xe máy', 'fine.min': 1000000, 'fine.max': 2000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 7, Khoản 5', 'score': 0.9488505125045776}
# {'violation.description': 'Không chấp hành hiệu lệnh, chỉ dẫn của người điều khiển giao thông hoặc người kiểm soát giao thông', 'vehicle': 'Xe thô sơ', 'fine.min': 100000, 'fine.max': 200000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 8, Khoản 2', 'score': 0.9488052129745483}

# %%
# Case 1: Specific Vehicle
results = search_with_filter("lạng lách đánh võng phạt bao nhiêu?")
for result in results:
    print(result)
# Result: Will ONLY return Car violations.

# Case 2: General Question
# results = search_with_filter("17 tuổi đi xe ô tô phạt bao nhiêu?")
# for result in results:
#     print(result)
# Out:
# 🔍 Filter: None | Search: lạng lách đánh võng phạt bao nhiêu? | Intent: lạng lách đánh võng
# {'violation.description': 'Khi làm nhiệm vụ mà trong cơ thể có chất kích thích khác mà pháp luật cầm sử dụng.', 'vehicle': 'Vi phạm khác', 'fine.min': 30000000, 'fine.max': 40000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 66, Khoản 7', 'score': 0.8619955778121948}
# {'violation.description': 'Mang, vác vật cồng kềnh gây cản trở giao thông', 'vehicle': 'Người đi bộ', 'fine.min': 60000, 'fine.max': 100000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 9, Khoản 1', 'score': 0.8134911060333252}
# {'violation.description': 'Xâm phạm sức khỏe, tài sản của người bị nạn hoặc người gây tai nạn', 'vehicle': 'Vi phạm khác', 'fine.min': 6000000, 'fine.max': 8000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 11, Khoản 10', 'score': 0.7581406831741333}
# {'violation.description': 'Tự ý đốt lửa trên cầu, dưới gầm cầu', 'vehicle': 'Vi phạm khác', 'fine.min': 200000, 'fine.max': 300000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 15, Khoản 2', 'score': 0.738703727722168}
# {'violation.description': 'Lợi dụng việc xảy ra tai nạn giao thông để hành hung, đe dọa, xúi giục, gây sức ép, làm mất trật tự, cản trở việc xử lý tai nạn giao thông.', 'vehicle': 'Vi phạm khác', 'fine.min': 6000000, 'fine.max': 8000000, 'clause.full_ref': 'Nghị định 100/2019/NĐ-CP, Điều 11, Khoản 10', 'score': 0.7077504396438599}

# %%
def hybrid_search(user_query):
    driver = GraphDatabase.driver(URI, auth=AUTH)
    extraction = extract_entities_with_llm(user_query, vehicle_patterns, business_patterns, fallback_patterns)
    target_category = extraction['category']
    query_intent = extraction['intent']

    if query_intent == None:
        print("Không biết.")
        return []
    # B. Embed the Query (The "Neuro" Search)
    # Note: We add "query:" prefix for the E5 model
    vector = model.encode(f"query: {query_intent}").tolist()
    
    print(f"🔍 Filter: {target_category} | Search: {user_query} | Intent: {query_intent}")
    # 1. Vector Search (Semantic)
    vector = model.encode(f"query: {query_intent}").tolist()
    vector_query = """
    CALL db.index.vector.queryNodes('violation_index', 50, $embedding)
    YIELD node, score
    RETURN node.id as id, node.description as text, score as vector_score
    """
    
    # 2. Keyword Search (BM25 - Lexical)
    # Cần xử lý query cho đúng cú pháp Lucene (VD: AND/OR)
    keyword_query = """
    CALL db.index.fulltext.queryNodes("violation_text_index", $text) 
    YIELD node, score
    RETURN node.id as id, node.description as text, score as bm25_score
    LIMIT 50
    """
    
    with driver.session() as session:
        vec_results = session.run(vector_query, embedding=vector).data()
        kw_results = session.run(keyword_query, text=query_intent).data()
        
    # 3. RRF Fusion (Gộp kết quả)
    final_scores = {}
    k = 60 # Hằng số thường dùng
    
    print("--------------------------------")
    # Cộng điểm từ Vector List
    for rank, item in enumerate(vec_results):
        doc_id = item['id']
        if doc_id not in final_scores: final_scores[doc_id] = {"data": item, "score": 0}
        final_scores[doc_id]["score"] += 1 / (k + rank + 1)
        print(f"Rank {rank+1}: id={item['id']} - Text: {item['text']} - Vector Score: {final_scores[doc_id]['score']:.4f}")
    
    print("--------------------------------")
    # Cộng điểm từ Keyword List
    for rank, item in enumerate(kw_results):
        doc_id = item['id']
        if doc_id not in final_scores: final_scores[doc_id] = {"data": item, "score": 0}
        # Nếu item xuất hiện ở cả 2 list, điểm sẽ rất cao
        final_scores[doc_id]["score"] += 1 / (k + rank + 1)
        print(f"Rank {rank+1}: id={item['id']} - Text: {item['text']} - BM25 Score: {final_scores[doc_id]['score']:.4f}")
    
    print("--------------------------------")
    # 4. Sort và lấy Top kết quả
    sorted_results = sorted(final_scores.values(), key=lambda x: x['score'], reverse=True)
    return sorted_results[:]

# %%
hybrid_search("tự ý mở lối đi từ nhà ra đường có bị phạt không")
# Out:
# 🔍 Filter: None | Search: tự ý mở lối đi từ nhà ra đường có bị phạt không | Intent: tự ý mở lối đi từ nhà ra đường
# --------------------------------
# Rank 1: id=297 - Text: Không đi đúng phần đường quy định - Vector Score: 0.0164
# Rank 2: id=14 - Text: Không tuân thủ các quy định về nhường đường tại nơi đường bộ giao nhau - Vector Score: 0.0161
# Rank 3: id=292 - Text: Đi ngược chiều đường của đường một chiều, đường có biển Cấm đi ngược chiều - Vector Score: 0.0159
# Rank 4: id=115 - Text: Không tuân thủ các quy định về nhường đường tại nơi đường giao nhau - Vector Score: 0.0156
# Rank 5: id=226 - Text: Không nhường đường cho хе đi ngược chiều theo quy định tại nơi đường hẹp, đường dốc, nơi có chướng ngại vật - Vector Score: 0.0154
# Rank 6: id=218 - Text: Đi không đúng phần đường hoặc làn đường quy định (làn cùng chiều hoặc làn ngược chiều) - Vector Score: 0.0152
# Rank 7: id=304 - Text: Không nhường đường theo quy định, không báo hiệu bằng tay khi chuyển hướng - Vector Score: 0.0149
# Rank 8: id=145 - Text: Đi không đúng phần đường, làn đường quy định (làn cùng chiều hoặc làn ngược chiều) - Vector Score: 0.0147
# Rank 9: id=74 - Text: Đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều - Vector Score: 0.0145
# Rank 10: id=229 - Text: Đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều - Vector Score: 0.0143
# Rank 11: id=217 - Text: Không đi bên phải theo chiều đi của mình - Vector Score: 0.0141
# Rank 12: id=262 - Text: Không đi bên phải theo chiều đi của mình, đi không đúng phần đường quy định - Vector Score: 0.0139
# Rank 13: id=107 - Text: Không có báo hiệu xin vượt trước khi vượt - Vector Score: 0.0137
# Rank 14: id=277 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - Vector Score: 0.0135
# Rank 15: id=55 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - Vector Score: 0.0133
# Rank 16: id=222 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - Vector Score: 0.0132
# Rank 17: id=130 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - Vector Score: 0.0130
# Rank 18: id=78 - Text: Đi không đúng phần đường hoặc làn đường quy định (làn cùng chiều hoặc làn ngược chiều) trừ hành vì quy định tại điểm c khoản 4 Điều này - Vector Score: 0.0128
# Rank 19: id=365 - Text: Mở đường nhánh đấu nối trái phép vào đường chính. - Vector Score: 0.0127
# Rank 20: id=148 - Text: Vượt bên phải trong trường hợp không được phép - Vector Score: 0.0125
# Rank 21: id=877 - Text: Điều khiển xe bánh xích, xe lu bánh sắt, các phương tiện vận chuyển hàng siêu trường, siêu trọng, quá khổ giới hạn đi qua đường ngang mà không thông báo cho tổ chức quản lý đường ngang, không thực hiện đúng các biện pháp bảo đảm an toàn. - Vector Score: 0.0123
# Rank 22: id=76 - Text: Không có báo hiệu trước khi vượt - Vector Score: 0.0122
# Rank 23: id=266 - Text: Vượt bên phải trong các trường hợp không được phép - Vector Score: 0.0120
# Rank 24: id=299 - Text: Đi qua đường không đúng nơi quy định hoặc không bảo đảm an toàn - Vector Score: 0.0119
# Rank 48: id=404 - Text: Phá dỡ trái phép dải phân cách, gương cầu, các công trình, thiết bị an toàn giao thông trên đường bộ, cấu kiện, phụ kiện của công trình đường bộ - Vector Score: 0.0093
# Rank 49: id=372 - Text: Không bố trí người hướng dẫn, điều khiển giao thông khi thi công ở chỗ đường hẹp hoặc ở hai đầu cầu, cống, đường ngầm đang thi công theo đúng quy định - Vector Score: 0.0092
# Rank 50: id=981 - Text: Không tổ chức thu hẹp bề rộng hoặc xóa bỏ lối đi tự mở là vị trí nguy hiểm đối với an toàn giao thông đường sắt theo quy định - Vector Score: 0.0091
# --------------------------------
# Rank 1: id=928 - Text: Tự mở lối đi qua đường sắt - BM25 Score: 0.0164
# Rank 2: id=926 - Text: Làm hỏng, tháo dỡ trái phép tường rào, hàng rào ngăn cách giữa đường sắt với khu vực xung quanh; làm sai lệch vị trí hoặc phá, dỡ trái phép mốc chỉ giới ga đường sắt, mốc giới đất dành cho đường sắt, hàng rào dùng để đóng lối đi tự mở, cọc dùng để thu hẹp lối đi tự mở - BM25 Score: 0.0161
# Rank 3: id=982 - Text: Không tổ chức cảnh giới, chốt gác tại lối đi tự mở là vị trí nguy hiểm đối với an toàn giao thông đường sắt theo quy định. - BM25 Score: 0.0159
# Rank 4: id=981 - Text: Không tổ chức thu hẹp bề rộng hoặc xóa bỏ lối đi tự mở là vị trí nguy hiểm đối với an toàn giao thông đường sắt theo quy định - BM25 Score: 0.0247
# Rank 5: id=904 - Text: Để vật chướng ngại lên đường sắt làm cản trở giao thông đường sắt; c) Tự ý mở chắn đường ngang khi chắn đã đóng. - BM25 Score: 0.0253
# Rank 6: id=405 - Text: Tự ý tháo, mở làm hư hỏng nắp cống, nắp ga các công trình ngầm, hệ thống tuy nen trên đường giao thông - BM25 Score: 0.0152
# Rank 7: id=970 - Text: Không lập danh mục quản lý đối với các đường ngang không phù hợp với quy định của Luật Đường sắt; không lập, không cập nhật hồ sơ các vị trí nguy hiểm đối với an toàn giao thông đường sắt, lối đi tự mở qua đường sắt - BM25 Score: 0.0149
# Rank 8: id=976 - Text: Không thực hiện chốt gác tại đường ngang là vị trí nguy hiểm đối với an toàn giao thông đường sắt trên đường sắt quốc gia; không thực hiện huấn luyện nghiệp vụ cảnh giới, chốt gác theo quy định cho người do địa phương bố trí để cảnh giới, chốt gác tại các lối đi tự mở - BM25 Score: 0.0147
# Rank 9: id=392 - Text: Tự ý be bờ, tát nước qua mặt đường giao thông - BM25 Score: 0.0145
# Rank 10: id=355 - Text: Tự ý gắn vào công trình báo hiệu đường bộ các nội dung không liên quan tới ý nghĩa, mục đích của công trình đường bộ - BM25 Score: 0.0250
# Rank 11: id=722 - Text: Đu, bám vào thành xe; đứng, ngồi, nằm trên mui xe, nóc xe, trong khoang chở hành lý; tự ý mở cửa xe hoặc có hành vi khác không bảo đảm an toàn khi xe đang chạy. - BM25 Score: 0.0141
# Rank 12: id=390 - Text: Tự ý đốt lửa trên cầu, dưới gầm cầu - BM25 Score: 0.0139
# Rank 13: id=794 - Text: Tự ý thay đổi hoặc sử dụng phần mềm sát hạch, thiết bị chấm điểm, chủng loại xe ô tô sát hạch khi chưa được sự chấp thuận của cơ quan quản lý nhà nước có thẩm quyền - BM25 Score: 0.0137
# Rank 14: id=649 - Text: Tự ý cắt, hàn, đục lại số khung, số máy - BM25 Score: 0.0135
# Rank 15: id=691 - Text: Tự ý thay đổi tính năng sử dụng của xe - BM25 Score: 0.0133
# Rank 16: id=663 - Text: Tự ý cắt, hàn, đục lại số khung, số máy - BM25 Score: 0.0132
# Rank 17: id=792 - Text: Trung tâm sát hạch lái xe tự ý di chuyển vị trí các phòng chức năng hoặc thay đổi hình các bài sát hạch mà chưa được chấp thuận của cơ quan quản lý nhà nước có thẩm quyền - BM25 Score: 0.0130
# Rank 18: id=1015 - Text: Tự ý thay đổi kết cấu, hình dáng, tính năng sử dụng của phương tiện giao thông đường sắt. - BM25 Score: 0.0128
# Rank 19: id=690 - Text: Tự ý thay đổi tổng thành khung, tổng thành máy (động cơ), hệ thống phanh, hệ thống truyền động (truyền lực), hệ thống chuyền động hoặc tự ý cải tạo kết cấu, hình dáng, kích thước của xe không đúng thiết kế của nhà sản xuất hoặc thiết kế đã đăng ký với cơ quan đăng ký xe hoặc thiết kế cải tạo đã được cơ quan có thẩm quyền phê duyệt - BM25 Score: 0.0127
# Rank 20: id=652 - Text: Tự ý thay đổi khung, máy, hình dáng, kích thước, đặc tính của xe - BM25 Score: 0.0125
# Rank 21: id=360 - Text: Xả nước thải xây dựng từ các công trình xây dựng ra đường phố - BM25 Score: 0.0123
# Rank 22: id=958 - Text: Thực hiện hành vi quy định tại điểm d khoản 3 Điều này buộc phải tháo dỡ, di chuyển các công trình, nhà ở, lều, quán gây trở ngại cho việc xây dựng, cải tạo, mở rộng và bảo đảm an toàn công trình đường sắt; g) Thực hiện hành vi quy định tại khoản 4 Điều này buộc phải tháo dỡ, di chuyển nhà, công trình, biển quảng cáo hoặc các biển chỉ dẫn xây dựng trái phép ra khỏi phạm vi đất dành cho đường sắt. - BM25 Score: 0.0122
# Rank 23: id=644 - Text: Tự ý thay đổi màu sơn của xe không đúng với màu sơn ghi trong Giấy đăng ký xe - BM25 Score: 0.0120
# Rank 24: id=399 - Text: Di chuyển chậm trễ các công trình, nhà, lều quán xây dựng trái phép hoặc cố tình trì hoãn việc di chuyển gây cản trở cho việc giải phóng mặt bằng để xây dựng, cải tạo, mở rộng và bảo vệ công trình đường bộ khi có quyết định của cơ quan nhà nước có thẩm quyền - BM25 Score: 0.0119
# Rank 25: id=125 - Text: Không giảm tốc độ và nhường đường khi điều khiển xe chạy từ trong ngõ, đường nhánh ra đường chính - BM25 Score: 0.0118
# Rank 26: id=54 - Text: Không giảm tốc độ và nhường đường khi điều khiển xe chạy từ trong ngõ, đường nhánh ra đường chính - BM25 Score: 0.0116
# Rank 27: id=386 - Text: Xây dựng hoặc thành lập bến xe, bãi đỗ xe, trạm dừng nghỉ, trạm thu phí đường bộ khi chưa được cơ quan quản lý nhà nước về giao thông vận tải đồng ý theo quy định - BM25 Score: 0.0115
# Rank 28: id=354 - Text: Tự ý đào, đắp, san, lấp mặt bằng trong: Hành lang an toàn đường bộ, phần đất dọc hai bên đường bộ dùng để quản lý, bảo trì, bảo vệ công trình đường bộ - BM25 Score: 0.0114
# Rank 29: id=365 - Text: Mở đường nhánh đấu nối trái phép vào đường chính. - BM25 Score: 0.0239
# Rank 30: id=950 - Text: Di chuyển chậm trễ các công trình, nhà ở, lều, quán hoặc cố tình trì hoãn việc di chuyển gây trở ngại cho việc xây dựng, cải tạo, mở rộng và bảo đảm an toàn công trình đường sắt khi có quyết định của cơ quan có thẩm quyền. - BM25 Score: 0.0111
# Rank 31: id=222 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - BM25 Score: 0.0241
# Rank 32: id=55 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - BM25 Score: 0.0242
# Rank 33: id=130 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - BM25 Score: 0.0237
# Rank 34: id=277 - Text: Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau - BM25 Score: 0.0242
# Rank 35: id=308 - Text: Đi dàn hàng ngang từ 02 xe trở lên - BM25 Score: 0.0105
# Rank 36: id=212 - Text: Mở cửa xe, để cửa xe mở không bảo đảm an toàn - BM25 Score: 0.0104
# Rank 37: id=21 - Text: Mở cửa xe, để cửa xe mở không bảo đảm an toàn - BM25 Score: 0.0103
# Rank 38: id=898 - Text: Đi, đứng, nằm, ngồi hoặc hành vi khác trên nóc toa xe, đầu máy, bậc lên xuống toa xe; đu bám, đứng, ngồi hai bên thành toa xe, đầu máy, nơi nối giữa các toa xe, đầu máy; mở cửa lên, xuống tàu, đưa đầu, tay, chân yà vật khác ra ngoài thành toa xe khi tàu đang chạy - BM25 Score: 0.0102
# Rank 39: id=415 - Text: Không thực hiện việc kết nối, chia sẻ dữ liệu từ trạm thu phí cho cơ quan quản lý nhà nước có thẩm quyền theo quy định. - BM25 Score: 0.0101
# Rank 40: id=402 - Text: Tự ý đập phá, tháo dỡ bỏ vỉa hè hoặc sửa chữa, cải tạo vỉa hè trái phép, trừ các hành vi vi phạm quy định tại điểm a, điểm c khoản 5 Điều này. - BM25 Score: 0.0100
# Rank 41: id=208 - Text: Nơi mở dải phân cách giữa - BM25 Score: 0.0099
# Rank 42: id=40 - Text: Nơi mở dải phân cách giữa - BM25 Score: 0.0098
# Rank 43: id=364 - Text: Chiếm dụng đất của đường bộ hoặc đất hành lang an toàn đường bộ để xây dựng nhà ở - BM25 Score: 0.0097
# Rank 44: id=401 - Text: Tự ý tháo dỡ, di chuyển, treo, đặt, làm hư hỏng, làm sai mục đích sử dụng hoặc làm sai lệch biển báo hiệu, đèn tín hiệu giao thông, rào chắn, cọc tiêu, cột cây số, vạch kẻ đường, tường bảo vệ, lan can phòng hộ, mốc chỉ giới - BM25 Score: 0.0096
# Rank 45: id=409 - Text: Không thực hiện đúng quy trình quản lý, vận hành theo quy định để thời gian đi qua trạm thu phí của một xe ô tô bất kỳ kể từ lúc dùng xe chờ thu phí đến lúc ra khỏi trạm thu phí lớn hơn 10 phút đến 20 phút. - BM25 Score: 0.0095
# Rank 46: id=411 - Text: Không thực hiện đúng quy trình quản lý, vận hành theo quy định để thời gian đi qua trạm thu phí của một xe ô tô bất kỳ kể từ lúc dừng xe chờ thu phí đến lúc ra khỏi trạm thu phí lớn hơn 20 phút đến 30 phút. - BM25 Score: 0.0094
# Rank 47: id=413 - Text: Không thực hiện đúng quy trình quản lý, vận hành theo quy định để thời gian đi qua trạm thu phí của một xe ô tô bất kỳ kể từ lúc dừng xe chờ thu phí đến lúc ra khỏi trạm thu phí lớn hơn 30 phút. 9. Phạt tiền từ 50.000.000 đồng đến 70.000.000 đồng đối với tổ chức quản lý, vận hành trạm thu phí đường bộ thực hiện một trong các hành vi vi phạm sau đây: - BM25 Score: 0.0093
# Rank 48: id=501 - Text: Sang nhượng hành khách dọc đường cho xe khác mà không được hành khách đồng ý - BM25 Score: 0.0093
# Rank 49: id=324 - Text: Lợi dụng việc xảy ra tai nạn giao thông để hành hung, đe dọa, xúi giục, gây sức ép, làm mất trật tự, cản trở việc xử lý tai nạn giao thông. - BM25 Score: 0.0092
# Rank 50: id=229 - Text: Đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều - BM25 Score: 0.0234
# --------------------------------
# [{'data': {'id': 904,
#    'text': 'Để vật chướng ngại lên đường sắt làm cản trở giao thông đường sắt; c) Tự ý mở chắn đường ngang khi chắn đã đóng.',
#    'vector_score': 0.8922538161277771},
#   'score': 0.02528560548362529},
#  {'data': {'id': 355,
#    'text': 'Tự ý gắn vào công trình báo hiệu đường bộ các nội dung không liên quan tới ý nghĩa, mục đích của công trình đường bộ',
#    'vector_score': 0.8996925354003906},
#   'score': 0.0250384024577573},
#  {'data': {'id': 981,
#    'text': 'Không tổ chức thu hẹp bề rộng hoặc xóa bỏ lối đi tự mở là vị trí nguy hiểm đối với an toàn giao thông đường sắt theo quy định',
#    'vector_score': 0.8872836828231812},
#   'score': 0.02471590909090909},
#  {'data': {'id': 55,
#    'text': 'Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau',
#    'vector_score': 0.9077160954475403},
#   'score': 0.02420289855072464},
#  {'data': {'id': 277,
#    'text': 'Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau',
#    'vector_score': 0.9077160954475403},
#   'score': 0.02415181138585394},
#  {'data': {'id': 222,
#    'text': 'Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau',
#    'vector_score': 0.9077160954475403},
#   'score': 0.024146905725853096},
#  {'data': {'id': 365,
#    'text': 'Mở đường nhánh đấu nối trái phép vào đường chính.',
#    'vector_score': 0.9069535732269287},
#   'score': 0.02389418290428104},
#  {'data': {'id': 130,
#    'text': 'Không nhường đường cho xe đi trên đường ưu tiên, đường chính từ bất kỳ hướng nào tới tại nơi đường giao nhau',
#    'vector_score': 0.9077160954475403},
#   'score': 0.023739701159056},
#  {'data': {'id': 229,
#    'text': 'Đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều',
#    'vector_score': 0.9111180305480957},
#   'score': 0.023376623376623377},
#  {'data': {'id': 297,
#    'text': 'Không đi đúng phần đường quy định',
#    'vector_score': 0.9217590093612671},
#   'score': 0.01639344262295082},
#  {'data': {'id': 928,
#    'text': 'Tự mở lối đi qua đường sắt',
#    'bm25_score': 10.18313980102539},
#   'score': 0.01639344262295082},
#  {'data': {'id': 14,
#    'text': 'Không tuân thủ các quy định về nhường đường tại nơi đường bộ giao nhau',
#    'vector_score': 0.9160770773887634},
#   'score': 0.016129032258064516},
#  {'data': {'id': 926,
#    'text': 'Làm hỏng, tháo dỡ trái phép tường rào, hàng rào ngăn cách giữa đường sắt với khu vực xung quanh; làm sai lệch vị trí hoặc phá, dỡ trái phép mốc chỉ giới ga đường sắt, mốc giới đất dành cho đường sắt, hàng rào dùng để đóng lối đi tự mở, cọc dùng để thu hẹp lối đi tự mở',
#    'bm25_score': 7.383588790893555},
#   'score': 0.016129032258064516},
#  {'data': {'id': 292,
#    'text': 'Đi ngược chiều đường của đường một chiều, đường có biển Cấm đi ngược chiều',
#    'vector_score': 0.9160498380661011},
#   'score': 0.015873015873015872},
#  {'data': {'id': 982,
#    'text': 'Không tổ chức cảnh giới, chốt gác tại lối đi tự mở là vị trí nguy hiểm đối với an toàn giao thông đường sắt theo quy định.',
#    'bm25_score': 7.014548301696777},
#   'score': 0.015873015873015872},
#  {'data': {'id': 115,
#    'text': 'Không tuân thủ các quy định về nhường đường tại nơi đường giao nhau',
#    'vector_score': 0.915825366973877},
#   'score': 0.015625},
#  {'data': {'id': 226,
#    'text': 'Không nhường đường cho хе đi ngược chiều theo quy định tại nơi đường hẹp, đường dốc, nơi có chướng ngại vật',
#    'vector_score': 0.9139912128448486},
#   'score': 0.015384615384615385},
#  {'data': {'id': 218,
#    'text': 'Đi không đúng phần đường hoặc làn đường quy định (làn cùng chiều hoặc làn ngược chiều)',
#    'vector_score': 0.9129998683929443},
#   'score': 0.015151515151515152},
#  {'data': {'id': 405,
#    'text': 'Tự ý tháo, mở làm hư hỏng nắp cống, nắp ga các công trình ngầm, hệ thống tuy nen trên đường giao thông',
#    'bm25_score': 5.719761371612549},
#   'score': 0.015151515151515152},
#  {'data': {'id': 304,
#    'text': 'Không nhường đường theo quy định, không báo hiệu bằng tay khi chuyển hướng',
#    'vector_score': 0.9125386476516724},
#   'score': 0.014925373134328358},
#  {'data': {'id': 970,
#    'text': 'Không lập danh mục quản lý đối với các đường ngang không phù hợp với quy định của Luật Đường sắt; không lập, không cập nhật hồ sơ các vị trí nguy hiểm đối với an toàn giao thông đường sắt, lối đi tự mở qua đường sắt',
#    'bm25_score': 5.717626094818115},
#   'score': 0.014925373134328358},
#  {'data': {'id': 145,
#    'text': 'Đi không đúng phần đường, làn đường quy định (làn cùng chiều hoặc làn ngược chiều)',
#    'vector_score': 0.9116256237030029},
#   'score': 0.014705882352941176},
#  {'data': {'id': 976,
#    'text': 'Không thực hiện chốt gác tại đường ngang là vị trí nguy hiểm đối với an toàn giao thông đường sắt trên đường sắt quốc gia; không thực hiện huấn luyện nghiệp vụ cảnh giới, chốt gác theo quy định cho người do địa phương bố trí để cảnh giới, chốt gác tại các lối đi tự mở',
#    'bm25_score': 5.201781272888184},
#   'score': 0.014705882352941176},
#  {'data': {'id': 74,
#    'text': 'Đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều',
#    'vector_score': 0.9111180305480957},
#   'score': 0.014492753623188406},
#  {'data': {'id': 392,
#    'text': 'Tự ý be bờ, tát nước qua mặt đường giao thông',
#    'bm25_score': 4.615337371826172},
#   'score': 0.014492753623188406},
#  {'data': {'id': 217,
#    'text': 'Không đi bên phải theo chiều đi của mình',
#    'vector_score': 0.909145712852478},
#   'score': 0.014084507042253521},
#  {'data': {'id': 722,
#    'text': 'Đu, bám vào thành xe; đứng, ngồi, nằm trên mui xe, nóc xe, trong khoang chở hành lý; tự ý mở cửa xe hoặc có hành vi khác không bảo đảm an toàn khi xe đang chạy.',
#    'bm25_score': 4.3072710037231445},
#   'score': 0.014084507042253521},
#  {'data': {'id': 262,
#    'text': 'Không đi bên phải theo chiều đi của mình, đi không đúng phần đường quy định',
#    'vector_score': 0.9087401032447815},
#   'score': 0.013888888888888888},
#  {'data': {'id': 390,
#    'text': 'Tự ý đốt lửa trên cầu, dưới gầm cầu',
#    'bm25_score': 4.229003429412842},
#   'score': 0.013888888888888888},
#  {'data': {'id': 107,
#    'text': 'Không có báo hiệu xin vượt trước khi vượt',
#    'vector_score': 0.9084486365318298},
#   'score': 0.0136986301369863},
#  {'data': {'id': 794,
#    'text': 'Tự ý thay đổi hoặc sử dụng phần mềm sát hạch, thiết bị chấm điểm, chủng loại xe ô tô sát hạch khi chưa được sự chấp thuận của cơ quan quản lý nhà nước có thẩm quyền',
#    'bm25_score': 4.192773342132568},
#   'score': 0.0136986301369863},
#  {'data': {'id': 649,
#    'text': 'Tự ý cắt, hàn, đục lại số khung, số máy',
#    'bm25_score': 4.143550872802734},
#   'score': 0.013513513513513514},
#  {'data': {'id': 691,
#    'text': 'Tự ý thay đổi tính năng sử dụng của xe',
#    'bm25_score': 4.143550872802734},
#   'score': 0.013333333333333334},
#  {'data': {'id': 663,
#    'text': 'Tự ý cắt, hàn, đục lại số khung, số máy',
#    'bm25_score': 4.143550872802734},
#   'score': 0.013157894736842105},
#  {'data': {'id': 792,
#    'text': 'Trung tâm sát hạch lái xe tự ý di chuyển vị trí các phòng chức năng hoặc thay đổi hình các bài sát hạch mà chưa được chấp thuận của cơ quan quản lý nhà nước có thẩm quyền',
#    'bm25_score': 4.139355659484863},
#   'score': 0.012987012987012988},
#  {'data': {'id': 78,
#    'text': 'Đi không đúng phần đường hoặc làn đường quy định (làn cùng chiều hoặc làn ngược chiều) trừ hành vì quy định tại điểm c khoản 4 Điều này',
#    'vector_score': 0.907084584236145},
#   'score': 0.01282051282051282},
#  {'data': {'id': 1015,
#    'text': 'Tự ý thay đổi kết cấu, hình dáng, tính năng sử dụng của phương tiện giao thông đường sắt.',
#    'bm25_score': 3.984064817428589},
#   'score': 0.01282051282051282},
#  {'data': {'id': 690,
#    'text': 'Tự ý thay đổi tổng thành khung, tổng thành máy (động cơ), hệ thống phanh, hệ thống truyền động (truyền lực), hệ thống chuyền động hoặc tự ý cải tạo kết cấu, hình dáng, kích thước của xe không đúng thiết kế của nhà sản xuất hoặc thiết kế đã đăng ký với cơ quan đăng ký xe hoặc thiết kế cải tạo đã được cơ quan có thẩm quyền phê duyệt',
#    'bm25_score': 3.9657678604125977},
#   'score': 0.012658227848101266},
#  {'data': {'id': 148,
#    'text': 'Vượt bên phải trong trường hợp không được phép',
#    'vector_score': 0.9061629772186279},
#   'score': 0.0125},
#  {'data': {'id': 652,
#    'text': 'Tự ý thay đổi khung, máy, hình dáng, kích thước, đặc tính của xe',
#    'bm25_score': 3.833690643310547},
#   'score': 0.0125},
#  {'data': {'id': 877,
#    'text': 'Điều khiển xe bánh xích, xe lu bánh sắt, các phương tiện vận chuyển hàng siêu trường, siêu trọng, quá khổ giới hạn đi qua đường ngang mà không thông báo cho tổ chức quản lý đường ngang, không thực hiện đúng các biện pháp bảo đảm an toàn.',
#    'vector_score': 0.9057811498641968},
#   'score': 0.012345679012345678},
#  {'data': {'id': 360,
#    'text': 'Xả nước thải xây dựng từ các công trình xây dựng ra đường phố',
#    'bm25_score': 3.5872626304626465},
#   'score': 0.012345679012345678},
#  {'data': {'id': 76,
#    'text': 'Không có báo hiệu trước khi vượt',
#    'vector_score': 0.90574711561203},
#   'score': 0.012195121951219513},
#  {'data': {'id': 958,
#    'text': 'Thực hiện hành vi quy định tại điểm d khoản 3 Điều này buộc phải tháo dỡ, di chuyển các công trình, nhà ở, lều, quán gây trở ngại cho việc xây dựng, cải tạo, mở rộng và bảo đảm an toàn công trình đường sắt; g) Thực hiện hành vi quy định tại khoản 4 Điều này buộc phải tháo dỡ, di chuyển nhà, công trình, biển quảng cáo hoặc các biển chỉ dẫn xây dựng trái phép ra khỏi phạm vi đất dành cho đường sắt.',
#    'bm25_score': 3.541646718978882},
#   'score': 0.012195121951219513},
#  {'data': {'id': 266,
#    'text': 'Vượt bên phải trong các trường hợp không được phép',
#    'vector_score': 0.9051475524902344},
#   'score': 0.012048192771084338},
#  {'data': {'id': 644,
#    'text': 'Tự ý thay đổi màu sơn của xe không đúng với màu sơn ghi trong Giấy đăng ký xe',
#    'bm25_score': 3.505964756011963},
#   'score': 0.012048192771084338},
#  {'data': {'id': 299,
#    'text': 'Đi qua đường không đúng nơi quy định hoặc không bảo đảm an toàn',
#    'vector_score': 0.9037792682647705},
#   'score': 0.011904761904761904},
#  {'data': {'id': 399,
#    'text': 'Di chuyển chậm trễ các công trình, nhà, lều quán xây dựng trái phép hoặc cố tình trì hoãn việc di chuyển gây cản trở cho việc giải phóng mặt bằng để xây dựng, cải tạo, mở rộng và bảo vệ công trình đường bộ khi có quyết định của cơ quan nhà nước có thẩm quyền',
#    'bm25_score': 3.499749183654785},
#   'score': 0.011904761904761904},
#  {'data': {'id': 337,
#    'text': 'Dụng cổng chào hoặc các vật che chắn khác trái quy định trong phạm vi đất dành cho đường bộ gây ảnh hưởng đến trật tự, an toàn giao thông đường bộ',
#    'vector_score': 0.903174877166748},
#   'score': 0.011764705882352941},
#  {'data': {'id': 125,
#    'text': 'Không giảm tốc độ và nhường đường khi điều khiển xe chạy từ trong ngõ, đường nhánh ra đường chính',
#    'bm25_score': 3.4530797004699707},
#   'score': 0.011764705882352941},
#  {'data': {'id': 287,
#    'text': 'Đuổi nhau trên đường',
#    'vector_score': 0.9028535485267639},
#   'score': 0.011627906976744186},
#  {'data': {'id': 54,
#    'text': 'Không giảm tốc độ và nhường đường khi điều khiển xe chạy từ trong ngõ, đường nhánh ra đường chính',
#    'bm25_score': 3.4530797004699707},
#   'score': 0.011627906976744186},
#  {'data': {'id': 320,
#    'text': 'Ném gạch, đất, đá, cát hoặc vật thể khác vào phương tiện đang tham gia giao thông trên đường bộ.',
#    'vector_score': 0.9026569128036499},
#   'score': 0.011494252873563218},
#  {'data': {'id': 386,
#    'text': 'Xây dựng hoặc thành lập bến xe, bãi đỗ xe, trạm dừng nghỉ, trạm thu phí đường bộ khi chưa được cơ quan quản lý nhà nước về giao thông vận tải đồng ý theo quy định',
#    'bm25_score': 3.415898561477661},
#   'score': 0.011494252873563218},
#  {'data': {'id': 116,
#    'text': 'Chuyển làn đường không đúng nơi được phép hoặc không có tín hiệu báo trước',
#    'vector_score': 0.9022289514541626},
#   'score': 0.011363636363636364},
#  {'data': {'id': 354,
#    'text': 'Tự ý đào, đắp, san, lấp mặt bằng trong: Hành lang an toàn đường bộ, phần đất dọc hai bên đường bộ dùng để quản lý, bảo trì, bảo vệ công trình đường bộ',
#    'bm25_score': 3.415282726287842},
#   'score': 0.011363636363636364},
#  {'data': {'id': 12,
#    'text': 'Chuyển làn đường không đúng nơi cho phép hoặc không có tín hiệu báo trước',
#    'vector_score': 0.901808500289917},
#   'score': 0.011235955056179775},
#  {'data': {'id': 111,
#    'text': 'Chuyển hướng không nhường đường cho: Các xe đi ngược chiều',
#    'vector_score': 0.9014337062835693},
#   'score': 0.011111111111111112},
#  {'data': {'id': 950,
#    'text': 'Di chuyển chậm trễ các công trình, nhà ở, lều, quán hoặc cố tình trì hoãn việc di chuyển gây trở ngại cho việc xây dựng, cải tạo, mở rộng và bảo đảm an toàn công trình đường sắt khi có quyết định của cơ quan có thẩm quyền.',
#    'bm25_score': 3.1111936569213867},
#   'score': 0.011111111111111112},
#  {'data': {'id': 5,
#    'text': 'Chuyển hướng không nhường đường cho: Các xe đi ngược chiều',
#    'vector_score': 0.9014337062835693},
#   'score': 0.01098901098901099},
#  {'data': {'id': 189,
#    'text': 'Chuyển hướng không nhường đường cho: Các xe đi ngược chiều',
#    'vector_score': 0.9014337062835693},
#   'score': 0.010869565217391304},
#  {'data': {'id': 265,
#    'text': 'Không chấp hành hiệu lệnh hoặc chỉ dẫn của biển báo hiệu, vạch kẻ đường',
#    'vector_score': 0.8971773982048035},
#   'score': 0.010638297872340425},
#  {'data': {'id': 328,
#    'text': 'Phơi thóc, lúa, rơm, rạ, nông, lâm, hải sản trên đường bộ',
#    'vector_score': 0.8958786725997925},
#   'score': 0.010526315789473684},
#  {'data': {'id': 308,
#    'text': 'Đi dàn hàng ngang từ 02 xe trở lên',
#    'bm25_score': 3.0687952041625977},
#   'score': 0.010526315789473684},
#  {'data': {'id': 3,
#    'text': 'Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ',
#    'vector_score': 0.8950942754745483},
#   'score': 0.010416666666666666},
#  {'data': {'id': 212,
#    'text': 'Mở cửa xe, để cửa xe mở không bảo đảm an toàn',
#    'bm25_score': 3.039093494415283},
#   'score': 0.010416666666666666},
#  {'data': {'id': 109,
#    'text': 'Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ',
#    'vector_score': 0.8950942754745483},
#   'score': 0.010309278350515464},
#  {'data': {'id': 21,
#    'text': 'Mở cửa xe, để cửa xe mở không bảo đảm an toàn',
#    'bm25_score': 3.039093494415283},
#   'score': 0.010309278350515464},
#  {'data': {'id': 187,
#    'text': 'Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ',
#    'vector_score': 0.8950942754745483},
#   'score': 0.01020408163265306},
#  {'data': {'id': 898,
#    'text': 'Đi, đứng, nằm, ngồi hoặc hành vi khác trên nóc toa xe, đầu máy, bậc lên xuống toa xe; đu bám, đứng, ngồi hai bên thành toa xe, đầu máy, nơi nối giữa các toa xe, đầu máy; mở cửa lên, xuống tàu, đưa đầu, tay, chân yà vật khác ra ngoài thành toa xe khi tàu đang chạy',
#    'bm25_score': 2.9961390495300293},
#   'score': 0.01020408163265306},
#  {'data': {'id': 204,
#    'text': 'Nơi đường bộ giao nhau hoặc trong phạm vi 05 m tính từ mép đường giao nhau',
#    'vector_score': 0.8939250707626343},
#   'score': 0.010101010101010102},
#  {'data': {'id': 415,
#    'text': 'Không thực hiện việc kết nối, chia sẻ dữ liệu từ trạm thu phí cho cơ quan quản lý nhà nước có thẩm quyền theo quy định.',
#    'bm25_score': 2.937969207763672},
#   'score': 0.010101010101010102},
#  {'data': {'id': 322,
#    'text': 'Chăng dây hoặc các vật cản khác qua đường gây nguy hiểm đến người và phương tiện tham gia giao thông',
#    'vector_score': 0.8924392461776733},
#   'score': 0.01},
#  {'data': {'id': 402,
#    'text': 'Tự ý đập phá, tháo dỡ bỏ vỉa hè hoặc sửa chữa, cải tạo vỉa hè trái phép, trừ các hành vi vi phạm quy định tại điểm a, điểm c khoản 5 Điều này.',
#    'bm25_score': 2.7528977394104004},
#   'score': 0.01},
#  {'data': {'id': 208,
#    'text': 'Nơi mở dải phân cách giữa',
#    'bm25_score': 2.7346811294555664},
#   'score': 0.009900990099009901},
#  {'data': {'id': 120,
#    'text': 'Không nhường đường cho xe đi ngược chiều theo quy định tại nơi đường hẹp, đường dốc, nơi có chướng ngại vật',
#    'vector_score': 0.8918685913085938},
#   'score': 0.00980392156862745},
#  {'data': {'id': 40,
#    'text': 'Nơi mở dải phân cách giữa',
#    'bm25_score': 2.7346811294555664},
#   'score': 0.00980392156862745},
#  {'data': {'id': 725,
#    'text': 'Điều khiển xe vượt quá khổ giới hạn của cầu, đường hoặc chở hàng vượt khổ giới hạn của cầu, đường tham gia giao thông',
#    'vector_score': 0.8913251161575317},
#   'score': 0.009708737864077669},
#  {'data': {'id': 364,
#    'text': 'Chiếm dụng đất của đường bộ hoặc đất hành lang an toàn đường bộ để xây dựng nhà ở',
#    'bm25_score': 2.6781625747680664},
#   'score': 0.009708737864077669},
#  {'data': {'id': 357,
#    'text': 'Dựng rạp, lều quán, công trình khác trái phép trong khu vực đô thị tại hầm đường bộ, cầu vượt, hầm cho người đi bộ, gầm cầu vượt',
#    'vector_score': 0.8912863731384277},
#   'score': 0.009615384615384616},
#  {'data': {'id': 401,
#    'text': 'Tự ý tháo dỡ, di chuyển, treo, đặt, làm hư hỏng, làm sai mục đích sử dụng hoặc làm sai lệch biển báo hiệu, đèn tín hiệu giao thông, rào chắn, cọc tiêu, cột cây số, vạch kẻ đường, tường bảo vệ, lan can phòng hộ, mốc chỉ giới',
#    'bm25_score': 2.66347074508667},
#   'score': 0.009615384615384616},
#  {'data': {'id': 396,
#    'text': 'Không phát hiện hoặc không có biện pháp ngăn chặn, báo cáo kịp thời các hành vi lấn chiếm, sử dụng trái phép hành lang an toàn giao thông đường bộ, phần đất dọc hai bên đường bộ dùng để quản lý, bảo trì, bảo vệ công trình đường bộ',
#    'vector_score': 0.8911378979682922},
#   'score': 0.009523809523809525},
#  {'data': {'id': 409,
#    'text': 'Không thực hiện đúng quy trình quản lý, vận hành theo quy định để thời gian đi qua trạm thu phí của một xe ô tô bất kỳ kể từ lúc dùng xe chờ thu phí đến lúc ra khỏi trạm thu phí lớn hơn 10 phút đến 20 phút.',
#    'bm25_score': 2.6507115364074707},
#   'score': 0.009523809523809525},
#  {'data': {'id': 207,
#    'text': 'Che khuất biển báo hiệu đường bộ',
#    'vector_score': 0.889947772026062},
#   'score': 0.009433962264150943},
#  {'data': {'id': 411,
#    'text': 'Không thực hiện đúng quy trình quản lý, vận hành theo quy định để thời gian đi qua trạm thu phí của một xe ô tô bất kỳ kể từ lúc dừng xe chờ thu phí đến lúc ra khỏi trạm thu phí lớn hơn 20 phút đến 30 phút.',
#    'bm25_score': 2.6507115364074707},
#   'score': 0.009433962264150943},
#  {'data': {'id': 39,
#    'text': 'Che khuất biển báo hiệu đường bộ',
#    'vector_score': 0.889947772026062},
#   'score': 0.009345794392523364},
#  {'data': {'id': 413,
#    'text': 'Không thực hiện đúng quy trình quản lý, vận hành theo quy định để thời gian đi qua trạm thu phí của một xe ô tô bất kỳ kể từ lúc dừng xe chờ thu phí đến lúc ra khỏi trạm thu phí lớn hơn 30 phút. 9. Phạt tiền từ 50.000.000 đồng đến 70.000.000 đồng đối với tổ chức quản lý, vận hành trạm thu phí đường bộ thực hiện một trong các hành vi vi phạm sau đây:',
#    'bm25_score': 2.5949904918670654},
#   'score': 0.009345794392523364},
#  {'data': {'id': 404,
#    'text': 'Phá dỡ trái phép dải phân cách, gương cầu, các công trình, thiết bị an toàn giao thông trên đường bộ, cấu kiện, phụ kiện của công trình đường bộ',
#    'vector_score': 0.8898954391479492},
#   'score': 0.009259259259259259},
#  {'data': {'id': 501,
#    'text': 'Sang nhượng hành khách dọc đường cho xe khác mà không được hành khách đồng ý',
#    'bm25_score': 2.549067735671997},
#   'score': 0.009259259259259259},
#  {'data': {'id': 372,
#    'text': 'Không bố trí người hướng dẫn, điều khiển giao thông khi thi công ở chỗ đường hẹp hoặc ở hai đầu cầu, cống, đường ngầm đang thi công theo đúng quy định',
#    'vector_score': 0.8897742033004761},
#   'score': 0.009174311926605505},
#  {'data': {'id': 324,
#    'text': 'Lợi dụng việc xảy ra tai nạn giao thông để hành hung, đe dọa, xúi giục, gây sức ép, làm mất trật tự, cản trở việc xử lý tai nạn giao thông.',
#    'bm25_score': 2.517660140991211},
#   'score': 0.009174311926605505}]

# %%
hybrid_search("không đội mũ bảo hiểm khi đi bộ thì phạt bao nhiêu?")
# Out:
# 🔍 Filter: Xe mô tô, xe máy | Search: không đội mũ lưỡi chai khi đi xe máy thì phạt bao nhiêu? | Intent: không đội mũ lưỡi chai khi đi xe máy
# --------------------------------
# Rank 1: id=1020 - Text: Không kiểm tra định kỳ và kẹp chì niêm phong van hãm khẩn cấp, đồng hồ áp suất theo quy định - Vector Score: 0.0164
# Rank 2: id=721 - Text: Mang hóa chất độc hại, chất dễ cháy, nổ, hàng nguy hiểm hoặc hàng cấm lưu thông trên xe khách - Vector Score: 0.0161
# Rank 3: id=1057 - Text: Khi làm nhiệm vụ mà trong máu hoặc hơi thở có nồng độ cồn vượt quá 80 miligam/100 mililít máu hoặc vượt quá 0,4 miligam/1 lít khí thở - Vector Score: 0.0159
# Rank 4: id=1056 - Text: Khi làm nhiệm vụ mà trong máu hoặc hơi thở có nồng độ cồn nhưng chưa vượt quá 50 miligam/100 mililít máu hoặc chưa vượt quá 0,25 miligam/1 lít khí thở. - Vector Score: 0.0156
# Rank 5: id=534 - Text: Chở công-ten-nơ trên xe (kể cả sơ mi rơ moóc) mà không sử dụng thiết bị để định vị chắc chắn công-ten-nơ với xe hoặc có sử dụng thiết bị nhưng công-ten-nơ vẫn bị xê dịch trong quá trình vận chuyển. - Vector Score: 0.0154
# Rank 6: id=1058 - Text: Không chấp hành yêu cầu kiểm tra về nồng độ cồn, chất kích thích khác mà pháp luật cầm sử dụng của người thi hành công vụ - Vector Score: 0.0152
# Rank 7: id=96 - Text: Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ - Vector Score: 0.0149
# Rank 8: id=254 - Text: Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ - Vector Score: 0.0147
# Rank 9: id=175 - Text: Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ - Vector Score: 0.0145
# Rank 10: id=321 - Text: Ném đỉnh, rải đinh hoặc vật sắc nhọn khác, đổ dầu nhờn hoặc các chất gây trơn khác trên đường bộ - Vector Score: 0.0143
# Rank 11: id=296 - Text: Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ. - Vector Score: 0.0141
# Rank 12: id=459 - Text: Để dầu nhờn, hóa chất rơi vãi xuống đường bộ - Vector Score: 0.0139
# Rank 13: id=1023 - Text: Thực hiện hành vi quy định tại điểm b khoản 1 Điều này buộc phải lắp đầy đủ theo đúng quy định hoặc thay thế thiết bị đủ tiêu chuẩn an toàn kỹ thuật hoặc khôi phục lại tính năng kỹ thuật của các thiết bị, gồm: van hãm khẩn cấp tại vị trí làm việc của trưởng tàu và trên toa xe khách - Vector Score: 0.0137
# Rank 14: id=1018 - Text: Trên phương tiện giao thông đường sắt không lắp thiết bị hãm tự động, hãm bằng tay hoặc có lắp thiết bị này nhưng thiết bị không hoạt động theo quy định - Vector Score: 0.0135
# Rank 15: id=920 - Text: Để chất dễ cháy, chất dễ nổ trong phạm vi bảo vệ công trình đường sắt, hành lang an toàn giao thông đường sắt - Vector Score: 0.0133
# Rank 16: id=342 - Text: Rửa xe, bơm nước mui xe gây ảnh hưởng đến trật tự an toàn giao thông đường bộ. - Vector Score: 0.0132
# Rank 36: id=632 - Text: Thực hiện hành vi quy định tại điểm d, điểm đ khoản 4 Điều này buộc phải gắn hộp đèn với chữ TAXI hoặc buộc phải niêm yết cụm từ XE ТАХI, ХЕ HỢP ĐỒNG, XE DU LỊCH theo đúng quy định - Vector Score: 0.0104
# Rank 37: id=423 - Text: Thực hiện hành vi quy định tại điểm a khoản 3, điểm d khoản 4 Điều này bị tịch thu đèn lắp thêm, còi vượt quá âm lượng: - Vector Score: 0.0103
# Rank 38: id=221 - Text: Bấm còi hơi, sử dụng đèn chiếu xa trong đô thị, khu đông dân cư - Vector Score: 0.0102
# Rank 39: id=32 - Text: Bấm còi hơi, sử dụng đèn chiếu xa trong đô thị, khu đông dân cư - Vector Score: 0.0101
# Rank 40: id=429 - Text: Thực hiện hành vi quy định tại điểm a, điểm e khoản 3 Điều này buộc phải lắp đầy đủ thiết bị hoặc khôi phục lại tính năng kỹ thuật của thiết bị theo quy định, tháo bỏ những thiết bị lắp thêm không đúng quy định. - Vector Score: 0.0100
# Rank 41: id=114 - Text: Chở người ngồi trên xe sử dụng ô (dù) - Vector Score: 0.0099
# Rank 42: id=1002 - Text: Thực hiện hành vi vi phạm quy định tại điểm b khoản 1 Điều này buộc phải bố trí đủ thiết bị an toàn và tín hiệu theo quy định - Vector Score: 0.0098
# Rank 43: id=461 - Text: Chở hàng hoặc chất thải để nước chảy xuống mặt đường gây mất an toàn giao thông và vệ sinh môi trường - Vector Score: 0.0097
# Rank 44: id=760 - Text: Sử dụng xe tập lái không có mui che mưa, nắng; không có ghế ngồi gắn chắc chắn trên thùng xe cho người học theo quy định - Vector Score: 0.0096
# Rank 45: id=1034 - Text: Thực hiện hành vi quy định tại điểm a khoản 3 Điều này buộc phải lắp đầy đủ theo đúng quy định hoặc thay thế thiết bị đủ tiêu chuẩn an toàn kỹ thuật hoặc khôi phục lại tính năng kỹ thuật của các thiết bị, gồm: đồng hồ báo - Vector Score: 0.0095
# Rank 46: id=834 - Text: Cho đầu máy dịch chuyển khi chưa nhận được kế hoạch dồn hoặc tín hiệu của người chỉ huy dồn cho phép - Vector Score: 0.0094
# Rank 47: id=407 - Text: Rải, đổ hóa chất gây hư hỏng công trình đường bộ. - Vector Score: 0.0093
# Rank 48: id=43 - Text: Đỗ xe trên miệng cống thoát nước, miệng hầm của đường điện thoại, điện cao thế, chỗ dành riêng cho xe chữa cháy lấy nước - Vector Score: 0.0093
# Rank 49: id=436 - Text: D) Sử dụng còi không đúng quy chuẩn kỹ thuật cho từng loại xe - Vector Score: 0.0092
# Rank 50: id=164 - Text: Sử dụng chân chống hoặc vật khác quệt xuống đường khi xe đang chạy - Vector Score: 0.0091
# --------------------------------
# Rank 1: id=137 - Text: Không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách khi điều khiển xe tham gia giao thông trên đường bộ - BM25 Score: 0.0164
# Rank 2: id=138 - Text: Chở người ngồi trên xe không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách - BM25 Score: 0.0161
# Rank 3: id=293 - Text: Người điều khiển xe đạp máy (kể cả xe đạp điện) không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách khi tham gia giao thông trên đường bộ - BM25 Score: 0.0159
# Rank 4: id=294 - Text: Chở người ngồi trên xe đạp máy (kể cả xe đạp điện) không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách - BM25 Score: 0.0156
# Rank 5: id=288 - Text: Đi xe bằng một bánh đối với xe đạp, xe đạp máy - BM25 Score: 0.0154
# Rank 6: id=898 - Text: Đi, đứng, nằm, ngồi hoặc hành vi khác trên nóc toa xe, đầu máy, bậc lên xuống toa xe; đu bám, đứng, ngồi hai bên thành toa xe, đầu máy, nơi nối giữa các toa xe, đầu máy; mở cửa lên, xuống tàu, đưa đầu, tay, chân yà vật khác ra ngoài thành toa xe khi tàu đang chạy - BM25 Score: 0.0152
# Rank 7: id=211 - Text: Rời vị trí lái, tắt máy khi dừng xe - BM25 Score: 0.0149
# Rank 8: id=25 - Text: Rời vị trí lái, tắt máy khi dừng xe - BM25 Score: 0.0147
# Rank 9: id=1047 - Text: Rời vị trí lái máy khi đầu máy đang hoạt động - BM25 Score: 0.0145
# Rank 10: id=47 - Text: Sử dụng đèn chiếu xa khi tránh xe đi ngược chiều - BM25 Score: 0.0143
# Rank 11: id=224 - Text: Sử dụng đèn chiếu xa khi tránh xe đi ngược chiều - BM25 Score: 0.0141
# Rank 12: id=119 - Text: Sử dụng đèn chiếu xa khi tránh xe đi ngược chiều - BM25 Score: 0.0139
# Rank 13: id=839 - Text: Để đầu máy, toa xe đỗ trên đường an toàn, đường lánh nạn khi không có lệnh của người có thẩm quyền - BM25 Score: 0.0137
# Rank 14: id=201 - Text: Dừng xe, đỗ xe tại các vị trí: Bên trái đường một chiều hoặc bên trái (theo hướng lưu thông) của đường đội - BM25 Score: 0.0135
# Rank 15: id=1035 - Text: Trưởng tàu để người đi, đứng, nằm, ngồi trên nóc toa xe, đu bám ngoài thành toa xe, đầu máy, chỗ nối hai đầu toa xe - BM25 Score: 0.0133
# Rank 16: id=261 - Text: Thực hiện hành vi quy định tại khoản 9 bị tước quyền sử dụng Giấy phép lái xe (khi điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiển xe máy chuyên dùng) từ 22 tháng đến 24 tháng. - BM25 Score: 0.0132
# Rank 17: id=1051 - Text: Không có hoặc có không đầy đủ cờ, đèn tín hiệu, pháo, chèn trên đầu máy khi lên ban theo quy định. - BM25 Score: 0.0130
# Rank 18: id=258 - Text: Thực hiện hành vi quy định tại khoản 8 Điều này thì bị tước quyền sử dụng Giấy phép lái xe (khi điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiến xe máy chuyên dùng) từ 05 tháng đến 07 tháng - BM25 Score: 0.0128
# Rank 19: id=260 - Text: Thực hiện hành vi quy định tại điểm b khoản 7 Điều này thì bị tước quyền sử dụng Giấy phép lái xe (khi điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiển xe máy chuyên dùng) từ 16 tháng đến 18 tháng - BM25 Score: 0.0127
# Rank 20: id=676 - Text: Không làm thủ tục đăng ký sang tên xe (để chuyển tên chủ xe trong Giấy đăng ký xe sang tên của mình) theo quy định khi mua, được cho, được tặng, được phân bổ, được điều chuyển, được thừa kế tài sản là xe ô tô, máy kéo, xe máy chuyên dùng, các loại xe tương tự xe ô tô - BM25 Score: 0.0125
# Rank 21: id=862 - Text: Không thông báo cho trực ban chạy tàu ga đến, ga đi, nhân viên điều độ chạy tàu tuyến về số hiệu tàu, giờ thực tế tàu đến, đi, thông qua sau khi tàu đến, đi, thông qua ga theo quy định - BM25 Score: 0.0123
# Rank 22: id=464 - Text: Người điều khiển xe mô tô, xe gắn máy, các loại xe tương tự xe mô tô và các loại xe tương tự xe gắn máy không mang theo Giấy đăng ký xe - BM25 Score: 0.0122
# Rank 23: id=487 - Text: Người điều khiển xe máy chuyên dùng không mang theo Giấy đăng ký xe - BM25 Score: 0.0120
# Rank 24: id=1037 - Text: Trưởng tàu, nhân viên phục vụ hành khách để người bán hàng rong trên tàu, để người không có vé đi tàu, để người lên, xuống tàu khi tàu đang chạy; để hành lý, hàng hóa ở hai đầu toa xe, bậc lên xuống hai đầu toa xe khi tàu đang chạy - BM25 Score: 0.0119
# Rank 25: id=317 - Text: Người được chở trên xe mô tô, xe gắn máy (kể cả xe máy điện), các loại xe tương tự xe mô tô và các loại xe tương tự xe gắn máy sử dụng ô (dù) - BM25 Score: 0.0118
# Rank 26: id=259 - Text: Thực hiện hành vi quy định tại điểm c khoản 6 Điều này thì bị tước quyền sử dụng Giấy phép lái xe (khỉ điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiển xe máy chuyên dùng) từ 10 tháng đến 12 tháng - BM25 Score: 0.0116
# Rank 27: id=262 - Text: Không đi bên phải theo chiều đi của mình, đi không đúng phần đường quy định - BM25 Score: 0.0115
# Rank 28: id=834 - Text: Cho đầu máy dịch chuyển khi chưa nhận được kế hoạch dồn hoặc tín hiệu của người chỉ huy dồn cho phép - BM25 Score: 0.0208
# Rank 29: id=463 - Text: Người điều khiển xe mô tô, xe gắn máy, các loại xe tương tự xe mô tô và các loại xe tương tự xe gắn máy không có hoặc không mang theo Giấy chứng nhận bảo hiểm trách nhiệm dân sự của chủ xe cơ giới còn hiệu lực - BM25 Score: 0.0112
# Rank 30: id=646 - Text: Không làm thủ tục đăng ký sang tên xe (để chuyển tên chủ xe trong Giấy đăng ký xe sang tên của mình) theo quy định khi mua, được cho, được tặng, được phân bổ, được điều chuyển, được thừa kế tài sản là xe mô tô, xe gắn máy, các loại xe tương tự xe mô tô - BM25 Score: 0.0111
# Rank 31: id=81 - Text: Tránh xe đi ngược chiều không đúng quy định không nhường đường cho xe đi ngược chiều theo quy định tại nơi đường hẹp, đường dốc, nơi có chướng ngại vật - BM25 Score: 0.0110
# Rank 32: id=454 - Text: Sử dụng Giấy đăng ký xe không đúng số khung, số máy của xe (kể cả rơ moóc). - BM25 Score: 0.0109
# Rank 33: id=189 - Text: Chuyển hướng không nhường đường cho: Các xe đi ngược chiều - BM25 Score: 0.0108
# Rank 34: id=5 - Text: Chuyển hướng không nhường đường cho: Các xe đi ngược chiều - BM25 Score: 0.0106
# Rank 35: id=111 - Text: Chuyển hướng không nhường đường cho: Các xe đi ngược chiều - BM25 Score: 0.0105
# Rank 36: id=3 - Text: Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ - BM25 Score: 0.0104
# Rank 37: id=187 - Text: Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ - BM25 Score: 0.0103
# Rank 38: id=109 - Text: Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ - BM25 Score: 0.0102
# Rank 39: id=217 - Text: Không đi bên phải theo chiều đi của mình - BM25 Score: 0.0101
# Rank 40: id=190 - Text: Người đi bộ, xe lăn của người khuyết tật đang qua đường tại nơi không có vạch kẻ đường cho người đi bộ. - BM25 Score: 0.0100
# Rank 41: id=6 - Text: Người đi bộ, xe lăn của người khuyết tật đang qua đường tại nơi không có vạch kẻ đường cho người đi bộ - BM25 Score: 0.0099
# Rank 42: id=112 - Text: Người đi bộ, xe lăn của người khuyết tật đang qua đường tại nơi không có vạch kẻ đường cho người đi bộ - BM25 Score: 0.0098
# Rank 43: id=439 - Text: Sử dụng Giấy đăng ký xe không đúng số khung, số máy của xe hoặc không do cơ quan có thẩm quyền cấp - BM25 Score: 0.0097
# Rank 44: id=92 - Text: Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông b) Điều khiển xe lạng lách, đánh võng - BM25 Score: 0.0096
# Rank 45: id=466 - Text: Người điều khiển xe ô tô, máy kéo và các loại xe tương tự xe ô tô không mang theo Giấy phép lái xe - BM25 Score: 0.0095
# Rank 46: id=491 - Text: Không đóng cửa lên xuống khi xe đang chạy - BM25 Score: 0.0094
# Rank 47: id=167 - Text: Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông - BM25 Score: 0.0093
# Rank 48: id=250 - Text: Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông - BM25 Score: 0.0093
# Rank 49: id=659 - Text: Đưa phương tiện có Giấy đăng ký xe nhưng không đúng với số khung số máy của xe tham gia giao thông - BM25 Score: 0.0092
# Rank 50: id=485 - Text: Người điều khiển xe máy chuyên dùng không đúng độ tuổi hoặc tuổi không phù hợp với ngành nghề theo quy định - BM25 Score: 0.0091
# --------------------------------
# [{'data': {'id': 834,
#    'text': 'Cho đầu máy dịch chuyển khi chưa nhận được kế hoạch dồn hoặc tín hiệu của người chỉ huy dồn cho phép',
#    'vector_score': 0.7671996355056763},
#   'score': 0.02079759862778731},
#  {'data': {'id': 1020,
#    'text': 'Không kiểm tra định kỳ và kẹp chì niêm phong van hãm khẩn cấp, đồng hồ áp suất theo quy định',
#    'vector_score': 0.8758026957511902},
#   'score': 0.01639344262295082},
#  {'data': {'id': 137,
#    'text': 'Không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách khi điều khiển xe tham gia giao thông trên đường bộ',
#    'bm25_score': 10.506348609924316},
#   'score': 0.01639344262295082},
#  {'data': {'id': 721,
#    'text': 'Mang hóa chất độc hại, chất dễ cháy, nổ, hàng nguy hiểm hoặc hàng cấm lưu thông trên xe khách',
#    'vector_score': 0.8636034727096558},
#   'score': 0.016129032258064516},
#  {'data': {'id': 138,
#    'text': 'Chở người ngồi trên xe không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách',
#    'bm25_score': 10.162493705749512},
#   'score': 0.016129032258064516},
#  {'data': {'id': 1057,
#    'text': 'Khi làm nhiệm vụ mà trong máu hoặc hơi thở có nồng độ cồn vượt quá 80 miligam/100 mililít máu hoặc vượt quá 0,4 miligam/1 lít khí thở',
#    'vector_score': 0.8588076829910278},
#   'score': 0.015873015873015872},
#  {'data': {'id': 293,
#    'text': 'Người điều khiển xe đạp máy (kể cả xe đạp điện) không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách khi tham gia giao thông trên đường bộ',
#    'bm25_score': 10.101405143737793},
#   'score': 0.015873015873015872},
#  {'data': {'id': 1056,
#    'text': 'Khi làm nhiệm vụ mà trong máu hoặc hơi thở có nồng độ cồn nhưng chưa vượt quá 50 miligam/100 mililít máu hoặc chưa vượt quá 0,25 miligam/1 lít khí thở.',
#    'vector_score': 0.8551872968673706},
#   'score': 0.015625},
#  {'data': {'id': 294,
#    'text': 'Chở người ngồi trên xe đạp máy (kể cả xe đạp điện) không đội mũ bảo hiểm cho người đi mô tô, xe máy hoặc đội mũ bảo hiểm cho người đi mô tô, xe máy không cài quai đúng quy cách',
#    'bm25_score': 9.847174644470215},
#   'score': 0.015625},
#  {'data': {'id': 534,
#    'text': 'Chở công-ten-nơ trên xe (kể cả sơ mi rơ moóc) mà không sử dụng thiết bị để định vị chắc chắn công-ten-nơ với xe hoặc có sử dụng thiết bị nhưng công-ten-nơ vẫn bị xê dịch trong quá trình vận chuyển.',
#    'vector_score': 0.8545480966567993},
#   'score': 0.015384615384615385},
#  {'data': {'id': 288,
#    'text': 'Đi xe bằng một bánh đối với xe đạp, xe đạp máy',
#    'bm25_score': 3.65065336227417},
#   'score': 0.015384615384615385},
#  {'data': {'id': 1058,
#    'text': 'Không chấp hành yêu cầu kiểm tra về nồng độ cồn, chất kích thích khác mà pháp luật cầm sử dụng của người thi hành công vụ',
#    'vector_score': 0.8498908877372742},
#   'score': 0.015151515151515152},
#  {'data': {'id': 898,
#    'text': 'Đi, đứng, nằm, ngồi hoặc hành vi khác trên nóc toa xe, đầu máy, bậc lên xuống toa xe; đu bám, đứng, ngồi hai bên thành toa xe, đầu máy, nơi nối giữa các toa xe, đầu máy; mở cửa lên, xuống tàu, đưa đầu, tay, chân yà vật khác ra ngoài thành toa xe khi tàu đang chạy',
#    'bm25_score': 3.557335376739502},
#   'score': 0.015151515151515152},
#  {'data': {'id': 96,
#    'text': 'Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ',
#    'vector_score': 0.8483099937438965},
#   'score': 0.014925373134328358},
#  {'data': {'id': 211,
#    'text': 'Rời vị trí lái, tắt máy khi dừng xe',
#    'bm25_score': 3.497025489807129},
#   'score': 0.014925373134328358},
#  {'data': {'id': 254,
#    'text': 'Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ',
#    'vector_score': 0.8483099937438965},
#   'score': 0.014705882352941176},
#  {'data': {'id': 25,
#    'text': 'Rời vị trí lái, tắt máy khi dừng xe',
#    'bm25_score': 3.497025489807129},
#   'score': 0.014705882352941176},
#  {'data': {'id': 175,
#    'text': 'Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ',
#    'vector_score': 0.8483099937438965},
#   'score': 0.014492753623188406},
#  {'data': {'id': 1047,
#    'text': 'Rời vị trí lái máy khi đầu máy đang hoạt động',
#    'bm25_score': 3.301726818084717},
#   'score': 0.014492753623188406},
#  {'data': {'id': 321,
#    'text': 'Ném đỉnh, rải đinh hoặc vật sắc nhọn khác, đổ dầu nhờn hoặc các chất gây trơn khác trên đường bộ',
#    'vector_score': 0.8468198776245117},
#   'score': 0.014285714285714285},
#  {'data': {'id': 47,
#    'text': 'Sử dụng đèn chiếu xa khi tránh xe đi ngược chiều',
#    'bm25_score': 3.1762797832489014},
#   'score': 0.014285714285714285},
#  {'data': {'id': 296,
#    'text': 'Không chấp hành yêu cầu kiểm tra về nồng độ cồn của người thi hành công vụ.',
#    'vector_score': 0.8417326211929321},
#   'score': 0.014084507042253521},
#  {'data': {'id': 224,
#    'text': 'Sử dụng đèn chiếu xa khi tránh xe đi ngược chiều',
#    'bm25_score': 3.1762797832489014},
#   'score': 0.014084507042253521},
#  {'data': {'id': 459,
#    'text': 'Để dầu nhờn, hóa chất rơi vãi xuống đường bộ',
#    'vector_score': 0.8393687605857849},
#   'score': 0.013888888888888888},
#  {'data': {'id': 119,
#    'text': 'Sử dụng đèn chiếu xa khi tránh xe đi ngược chiều',
#    'bm25_score': 3.1762797832489014},
#   'score': 0.013888888888888888},
#  {'data': {'id': 1023,
#    'text': 'Thực hiện hành vi quy định tại điểm b khoản 1 Điều này buộc phải lắp đầy đủ theo đúng quy định hoặc thay thế thiết bị đủ tiêu chuẩn an toàn kỹ thuật hoặc khôi phục lại tính năng kỹ thuật của các thiết bị, gồm: van hãm khẩn cấp tại vị trí làm việc của trưởng tàu và trên toa xe khách',
#    'vector_score': 0.8344855308532715},
#   'score': 0.0136986301369863},
#  {'data': {'id': 839,
#    'text': 'Để đầu máy, toa xe đỗ trên đường an toàn, đường lánh nạn khi không có lệnh của người có thẩm quyền',
#    'bm25_score': 3.103680372238159},
#   'score': 0.0136986301369863},
#  {'data': {'id': 1018,
#    'text': 'Trên phương tiện giao thông đường sắt không lắp thiết bị hãm tự động, hãm bằng tay hoặc có lắp thiết bị này nhưng thiết bị không hoạt động theo quy định',
#    'vector_score': 0.8282051086425781},
#   'score': 0.013513513513513514},
#  {'data': {'id': 201,
#    'text': 'Dừng xe, đỗ xe tại các vị trí: Bên trái đường một chiều hoặc bên trái (theo hướng lưu thông) của đường đội',
#    'bm25_score': 3.083993911743164},
#   'score': 0.013513513513513514},
#  {'data': {'id': 920,
#    'text': 'Để chất dễ cháy, chất dễ nổ trong phạm vi bảo vệ công trình đường sắt, hành lang an toàn giao thông đường sắt',
#    'vector_score': 0.8242254853248596},
#   'score': 0.013333333333333334},
#  {'data': {'id': 1035,
#    'text': 'Trưởng tàu để người đi, đứng, nằm, ngồi trên nóc toa xe, đu bám ngoài thành toa xe, đầu máy, chỗ nối hai đầu toa xe',
#    'bm25_score': 2.9345333576202393},
#   'score': 0.013333333333333334},
#  {'data': {'id': 342,
#    'text': 'Rửa xe, bơm nước mui xe gây ảnh hưởng đến trật tự an toàn giao thông đường bộ.',
#    'vector_score': 0.8226704597473145},
#   'score': 0.013157894736842105},
#  {'data': {'id': 261,
#    'text': 'Thực hiện hành vi quy định tại khoản 9 bị tước quyền sử dụng Giấy phép lái xe (khi điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiển xe máy chuyên dùng) từ 22 tháng đến 24 tháng.',
#    'bm25_score': 2.877314329147339},
#   'score': 0.013157894736842105},
#  {'data': {'id': 1019,
#    'text': 'Không lắp van hãm khẩn cấp trên toa xe khách, tại vị trí làm việc của trưởng tàu hoặc có lắp thiết bị này nhưng thiết bị không hoạt động theo quy định',
#    'vector_score': 0.8216876983642578},
#   'score': 0.012987012987012988},
#  {'data': {'id': 1051,
#    'text': 'Không có hoặc có không đầy đủ cờ, đèn tín hiệu, pháo, chèn trên đầu máy khi lên ban theo quy định.',
#    'bm25_score': 2.8405609130859375},
#   'score': 0.012987012987012988},
#  {'data': {'id': 451,
#    'text': 'Không có bộ phận giảm thanh, giảm khói hoặc có nhưng không có tác dụng, không bảo đảm quy chuẩn môi trường về khí thải, tiếng ồn',
#    'vector_score': 0.8180869817733765},
#   'score': 0.01282051282051282},
#  {'data': {'id': 258,
#    'text': 'Thực hiện hành vi quy định tại khoản 8 Điều này thì bị tước quyền sử dụng Giấy phép lái xe (khi điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiến xe máy chuyên dùng) từ 05 tháng đến 07 tháng',
#    'bm25_score': 2.782871961593628},
#   'score': 0.01282051282051282},
#  {'data': {'id': 1022,
#    'text': 'Thực hiện hành vi quy định tại điểm a khoản 1 Điều này buộc phải lắp đầy đủ theo đúng quy định hoặc thay thế thiết bị đủ tiêu chuẩn an toàn kỹ thuật hoặc khôi phục lại tính năng kỹ thuật của các thiết bị, gồm: thiết bị hãm tự động, hãm bằng tay',
#    'vector_score': 0.8133372664451599},
#   'score': 0.012658227848101266},
#  {'data': {'id': 260,
#    'text': 'Thực hiện hành vi quy định tại điểm b khoản 7 Điều này thì bị tước quyền sử dụng Giấy phép lái xe (khi điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiển xe máy chuyên dùng) từ 16 tháng đến 18 tháng',
#    'bm25_score': 2.737938165664673},
#   'score': 0.012658227848101266},
#  {'data': {'id': 302,
#    'text': 'Mang, vác vật cồng kềnh gây cản trở giao thông',
#    'vector_score': 0.8066676259040833},
#   'score': 0.0125},
#  {'data': {'id': 676,
#    'text': 'Không làm thủ tục đăng ký sang tên xe (để chuyển tên chủ xe trong Giấy đăng ký xe sang tên của mình) theo quy định khi mua, được cho, được tặng, được phân bổ, được điều chuyển, được thừa kế tài sản là xe ô tô, máy kéo, xe máy chuyên dùng, các loại xe tương tự xe ô tô',
#    'bm25_score': 2.7054431438446045},
#   'score': 0.0125},
#  {'data': {'id': 1024,
#    'text': 'Thực hiện hành vi quy định tại điểm d khoản 1 Điều này buộc phải lắp đầy đủ theo đúng quy định hoặc thay thế thiết bị đủ tiêu chuẩn an toàn kỹ thuật hoặc khôi phục lại tính năng kỹ thuật của các thiết bị, gồm: đồng hồ áp suất tại vị trí làm việc của trưởng tàu, trên một số toa xe khách',
#    'vector_score': 0.8055663108825684},
#   'score': 0.012345679012345678},
#  {'data': {'id': 862,
#    'text': 'Không thông báo cho trực ban chạy tàu ga đến, ga đi, nhân viên điều độ chạy tàu tuyến về số hiệu tàu, giờ thực tế tàu đến, đi, thông qua sau khi tàu đến, đi, thông qua ga theo quy định',
#    'bm25_score': 2.5884761810302734},
#   'score': 0.012345679012345678},
#  {'data': {'id': 24,
#    'text': 'Dừng xe trên miệng cống thoát nước, miệng hầm của đường điện thoại, điện cao thế, chỗ dành riêng cho xe chữa cháy lấy nước',
#    'vector_score': 0.8052076697349548},
#   'score': 0.012195121951219513},
#  {'data': {'id': 464,
#    'text': 'Người điều khiển xe mô tô, xe gắn máy, các loại xe tương tự xe mô tô và các loại xe tương tự xe gắn máy không mang theo Giấy đăng ký xe',
#    'bm25_score': 2.539966583251953},
#   'score': 0.012195121951219513},
#  {'data': {'id': 933,
#    'text': 'Thực hiện hành vi quy định tại điểm c khoản 2 Điều này buộc phải đưa chất dễ cháy, dễ nổ ra khỏi phạm vi đất dành cho đường sắt',
#    'vector_score': 0.803764820098877},
#   'score': 0.012048192771084338},
#  {'data': {'id': 487,
#    'text': 'Người điều khiển xe máy chuyên dùng không mang theo Giấy đăng ký xe',
#    'bm25_score': 2.4976553916931152},
#   'score': 0.012048192771084338},
#  {'data': {'id': 1025,
#    'text': 'Thực hiện hành vi quy định tại điểm đ khoản 1 Điều này buộc phải lắp thiết bị ghép nối đầu máy, toa xe theo đúng quy định',
#    'vector_score': 0.8008401989936829},
#   'score': 0.011904761904761904},
#  {'data': {'id': 1037,
#    'text': 'Trưởng tàu, nhân viên phục vụ hành khách để người bán hàng rong trên tàu, để người không có vé đi tàu, để người lên, xuống tàu khi tàu đang chạy; để hành lý, hàng hóa ở hai đầu toa xe, bậc lên xuống hai đầu toa xe khi tàu đang chạy',
#    'bm25_score': 2.4626784324645996},
#   'score': 0.011904761904761904},
#  {'data': {'id': 163,
#    'text': 'Người đang điều khiển xe sử dụng ô (dù), điện thoại di động, thiết bị âm thanh, trừ thiết bị trợ thính.',
#    'vector_score': 0.7996281385421753},
#   'score': 0.011764705882352941},
#  {'data': {'id': 317,
#    'text': 'Người được chở trên xe mô tô, xe gắn máy (kể cả xe máy điện), các loại xe tương tự xe mô tô và các loại xe tương tự xe gắn máy sử dụng ô (dù)',
#    'bm25_score': 2.451569080352783},
#   'score': 0.011764705882352941},
#  {'data': {'id': 10,
#    'text': 'Điều khiển xe kéo rơ moóc không có biển báo hiệu theo quy định',
#    'vector_score': 0.7933067679405212},
#   'score': 0.011627906976744186},
#  {'data': {'id': 259,
#    'text': 'Thực hiện hành vi quy định tại điểm c khoản 6 Điều này thì bị tước quyền sử dụng Giấy phép lái xe (khỉ điều khiển máy kéo), chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ (khi điều khiển xe máy chuyên dùng) từ 10 tháng đến 12 tháng',
#    'bm25_score': 2.3908212184906006},
#   'score': 0.011627906976744186},
#  {'data': {'id': 220,
#    'text': 'Bấm còi, rú ga liên tục',
#    'vector_score': 0.7931883335113525},
#   'score': 0.011494252873563218},
#  {'data': {'id': 262,
#    'text': 'Không đi bên phải theo chiều đi của mình, đi không đúng phần đường quy định',
#    'bm25_score': 2.38712215423584},
#   'score': 0.011494252873563218},
#  {'data': {'id': 31,
#    'text': 'Bấm còi, rú ga liên tục',
#    'vector_score': 0.7931883335113525},
#   'score': 0.011363636363636364},
#  {'data': {'id': 643,
#    'text': 'Lắp kính chắn gió, kính cửa của xe không phải là loại kính an toàn',
#    'vector_score': 0.7931842803955078},
#   'score': 0.011235955056179775},
#  {'data': {'id': 463,
#    'text': 'Người điều khiển xe mô tô, xe gắn máy, các loại xe tương tự xe mô tô và các loại xe tương tự xe gắn máy không có hoặc không mang theo Giấy chứng nhận bảo hiểm trách nhiệm dân sự của chủ xe cơ giới còn hiệu lực',
#    'bm25_score': 2.3676273822784424},
#   'score': 0.011235955056179775},
#  {'data': {'id': 1021,
#    'text': 'Không lắp đồng hồ áp suất tại vị trí làm việc của trưởng tàu, trên một số toa xe khách theo quy định hoặc có lắp thiết bị này nhưng thiết bị không hoạt động theo quy định; đ) Để thiết bị ghép nối đầu máy, toa xe không đúng quy định.',
#    'vector_score': 0.7925437092781067},
#   'score': 0.011111111111111112},
#  {'data': {'id': 646,
#    'text': 'Không làm thủ tục đăng ký sang tên xe (để chuyển tên chủ xe trong Giấy đăng ký xe sang tên của mình) theo quy định khi mua, được cho, được tặng, được phân bổ, được điều chuyển, được thừa kế tài sản là xe mô tô, xe gắn máy, các loại xe tương tự xe mô tô',
#    'bm25_score': 2.34304141998291},
#   'score': 0.011111111111111112},
#  {'data': {'id': 393,
#    'text': 'Đặt ống bơm nước, bơm cát qua đường, đốt lửa trên mặt đường.',
#    'vector_score': 0.7916967868804932},
#   'score': 0.01098901098901099},
#  {'data': {'id': 81,
#    'text': 'Tránh xe đi ngược chiều không đúng quy định không nhường đường cho xe đi ngược chiều theo quy định tại nơi đường hẹp, đường dốc, nơi có chướng ngại vật',
#    'bm25_score': 2.3388149738311768},
#   'score': 0.01098901098901099},
#  {'data': {'id': 1108,
#    'text': 'Mang chất dễ cháy, dễ nổ, vũ khí, hàng nguy hiểm vào ga, lên tàu trái quy định',
#    'vector_score': 0.7878702878952026},
#   'score': 0.010869565217391304},
#  {'data': {'id': 454,
#    'text': 'Sử dụng Giấy đăng ký xe không đúng số khung, số máy của xe (kể cả rơ moóc).',
#    'bm25_score': 2.337287187576294},
#   'score': 0.010869565217391304},
#  {'data': {'id': 49,
#    'text': 'Điều khiển xe kéo rơ moóc, sơ mi rơ moóc kéo thêm rơ moóc hoặc xe khác, vật khác',
#    'vector_score': 0.7855556011199951},
#   'score': 0.010752688172043012},
#  {'data': {'id': 189,
#    'text': 'Chuyển hướng không nhường đường cho: Các xe đi ngược chiều',
#    'bm25_score': 2.3361995220184326},
#   'score': 0.010752688172043012},
#  {'data': {'id': 841,
#    'text': 'Tiến hành dồn khi các toa xe trong đoàn dồn chưa treo hàm nối ống mềm vào chỗ quy định',
#    'vector_score': 0.7854689955711365},
#   'score': 0.010638297872340425},
#  {'data': {'id': 5,
#    'text': 'Chuyển hướng không nhường đường cho: Các xe đi ngược chiều',
#    'bm25_score': 2.3361995220184326},
#   'score': 0.010638297872340425},
#  {'data': {'id': 990,
#    'text': 'Không bố trí đủ thiết bị an toàn và tín hiệu theo quy định đối với phương tiện, thiết bị thi công',
#    'vector_score': 0.7826635837554932},
#   'score': 0.010526315789473684},
#  {'data': {'id': 111,
#    'text': 'Chuyển hướng không nhường đường cho: Các xe đi ngược chiều',
#    'bm25_score': 2.3361995220184326},
#   'score': 0.010526315789473684},
#  {'data': {'id': 632,
#    'text': 'Thực hiện hành vi quy định tại điểm d, điểm đ khoản 4 Điều này buộc phải gắn hộp đèn với chữ TAXI hoặc buộc phải niêm yết cụm từ XE ТАХI, ХЕ HỢP ĐỒNG, XE DU LỊCH theo đúng quy định',
#    'vector_score': 0.7812487483024597},
#   'score': 0.010416666666666666},
#  {'data': {'id': 3,
#    'text': 'Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ',
#    'bm25_score': 2.3309311866760254},
#   'score': 0.010416666666666666},
#  {'data': {'id': 423,
#    'text': 'Thực hiện hành vi quy định tại điểm a khoản 3, điểm d khoản 4 Điều này bị tịch thu đèn lắp thêm, còi vượt quá âm lượng:',
#    'vector_score': 0.7783401012420654},
#   'score': 0.010309278350515464},
#  {'data': {'id': 187,
#    'text': 'Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ',
#    'bm25_score': 2.3309311866760254},
#   'score': 0.010309278350515464},
#  {'data': {'id': 221,
#    'text': 'Bấm còi hơi, sử dụng đèn chiếu xa trong đô thị, khu đông dân cư',
#    'vector_score': 0.7761954665184021},
#   'score': 0.01020408163265306},
#  {'data': {'id': 109,
#    'text': 'Chuyển hướng không nhường quyền đi trước cho: Người đi bộ, xe lăn của người khuyết tật qua đường tại nơi có vạch kẻ đường dành cho người đi bộ',
#    'bm25_score': 2.3309311866760254},
#   'score': 0.01020408163265306},
#  {'data': {'id': 32,
#    'text': 'Bấm còi hơi, sử dụng đèn chiếu xa trong đô thị, khu đông dân cư',
#    'vector_score': 0.7761954665184021},
#   'score': 0.010101010101010102},
#  {'data': {'id': 217,
#    'text': 'Không đi bên phải theo chiều đi của mình',
#    'bm25_score': 2.297455310821533},
#   'score': 0.010101010101010102},
#  {'data': {'id': 429,
#    'text': 'Thực hiện hành vi quy định tại điểm a, điểm e khoản 3 Điều này buộc phải lắp đầy đủ thiết bị hoặc khôi phục lại tính năng kỹ thuật của thiết bị theo quy định, tháo bỏ những thiết bị lắp thêm không đúng quy định.',
#    'vector_score': 0.7760522365570068},
#   'score': 0.01},
#  {'data': {'id': 190,
#    'text': 'Người đi bộ, xe lăn của người khuyết tật đang qua đường tại nơi không có vạch kẻ đường cho người đi bộ.',
#    'bm25_score': 2.2931618690490723},
#   'score': 0.01},
#  {'data': {'id': 114,
#    'text': 'Chở người ngồi trên xe sử dụng ô (dù)',
#    'vector_score': 0.772737979888916},
#   'score': 0.009900990099009901},
#  {'data': {'id': 6,
#    'text': 'Người đi bộ, xe lăn của người khuyết tật đang qua đường tại nơi không có vạch kẻ đường cho người đi bộ',
#    'bm25_score': 2.2931618690490723},
#   'score': 0.009900990099009901},
#  {'data': {'id': 1002,
#    'text': 'Thực hiện hành vi vi phạm quy định tại điểm b khoản 1 Điều này buộc phải bố trí đủ thiết bị an toàn và tín hiệu theo quy định',
#    'vector_score': 0.7723599672317505},
#   'score': 0.00980392156862745},
#  {'data': {'id': 112,
#    'text': 'Người đi bộ, xe lăn của người khuyết tật đang qua đường tại nơi không có vạch kẻ đường cho người đi bộ',
#    'bm25_score': 2.2931618690490723},
#   'score': 0.00980392156862745},
#  {'data': {'id': 461,
#    'text': 'Chở hàng hoặc chất thải để nước chảy xuống mặt đường gây mất an toàn giao thông và vệ sinh môi trường',
#    'vector_score': 0.7700483798980713},
#   'score': 0.009708737864077669},
#  {'data': {'id': 439,
#    'text': 'Sử dụng Giấy đăng ký xe không đúng số khung, số máy của xe hoặc không do cơ quan có thẩm quyền cấp',
#    'bm25_score': 2.2819325923919678},
#   'score': 0.009708737864077669},
#  {'data': {'id': 760,
#    'text': 'Sử dụng xe tập lái không có mui che mưa, nắng; không có ghế ngồi gắn chắc chắn trên thùng xe cho người học theo quy định',
#    'vector_score': 0.7692378163337708},
#   'score': 0.009615384615384616},
#  {'data': {'id': 92,
#    'text': 'Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông b) Điều khiển xe lạng lách, đánh võng',
#    'bm25_score': 2.2571001052856445},
#   'score': 0.009615384615384616},
#  {'data': {'id': 1034,
#    'text': 'Thực hiện hành vi quy định tại điểm a khoản 3 Điều này buộc phải lắp đầy đủ theo đúng quy định hoặc thay thế thiết bị đủ tiêu chuẩn an toàn kỹ thuật hoặc khôi phục lại tính năng kỹ thuật của các thiết bị, gồm: đồng hồ báo',
#    'vector_score': 0.7686476707458496},
#   'score': 0.009523809523809525},
#  {'data': {'id': 466,
#    'text': 'Người điều khiển xe ô tô, máy kéo và các loại xe tương tự xe ô tô không mang theo Giấy phép lái xe',
#    'bm25_score': 2.2393875122070312},
#   'score': 0.009523809523809525},
#  {'data': {'id': 491,
#    'text': 'Không đóng cửa lên xuống khi xe đang chạy',
#    'bm25_score': 2.23449444770813},
#   'score': 0.009433962264150943},
#  {'data': {'id': 407,
#    'text': 'Rải, đổ hóa chất gây hư hỏng công trình đường bộ.',
#    'vector_score': 0.7662537693977356},
#   'score': 0.009345794392523364},
#  {'data': {'id': 167,
#    'text': 'Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông',
#    'bm25_score': 2.221679925918579},
#   'score': 0.009345794392523364},
#  {'data': {'id': 43,
#    'text': 'Đỗ xe trên miệng cống thoát nước, miệng hầm của đường điện thoại, điện cao thế, chỗ dành riêng cho xe chữa cháy lấy nước',
#    'vector_score': 0.7655165195465088},
#   'score': 0.009259259259259259},
#  {'data': {'id': 250,
#    'text': 'Không đi đúng phần đường, làn đường, không giữ khoảng cách an toàn giữa hai xe theo quy định gây tai nạn giao thông hoặc đi vào đường có biển báo hiệu có nội dung cấm đi vào đối với loại phương tiện đang điều khiển, đi ngược chiều của đường một chiều, đi ngược chiều trên đường có biển Cấm đi ngược chiều gây tai nạn giao thông',
#    'bm25_score': 2.221679925918579},
#   'score': 0.009259259259259259},
#  {'data': {'id': 436,
#    'text': 'D) Sử dụng còi không đúng quy chuẩn kỹ thuật cho từng loại xe',
#    'vector_score': 0.7641401290893555},
#   'score': 0.009174311926605505},
#  {'data': {'id': 659,
#    'text': 'Đưa phương tiện có Giấy đăng ký xe nhưng không đúng với số khung số máy của xe tham gia giao thông',
#    'bm25_score': 2.1966915130615234},
#   'score': 0.009174311926605505},
#  {'data': {'id': 164,
#    'text': 'Sử dụng chân chống hoặc vật khác quệt xuống đường khi xe đang chạy',
#    'vector_score': 0.7626707553863525},
#   'score': 0.00909090909090909},
#  {'data': {'id': 485,
#    'text': 'Người điều khiển xe máy chuyên dùng không đúng độ tuổi hoặc tuổi không phù hợp với ngành nghề theo quy định',
#    'bm25_score': 2.185072183609009},
#   'score': 0.00909090909090909}]

# %% [markdown]
# # fix test set (id)

# %%
with open("./data/test_set.json", "r") as f:
    test_data = json.load(f)

with open("./data/processed/violations_100.json", "r") as f:
    data_100 = json.load(f)

# %%
for test_idx in range(len(test_data)):
    test_item = test_data[test_idx]
    for data_idx in range(len(data_100['violations'])):
        if test_item["id"] != -1:
            if test_item['description'].lower() in data_100['violations'][data_idx]['description'].lower() and test_item['category'].lower() in data_100['violations'][data_idx]['category'].lower():
                test_item['id'] = data_100['violations'][data_idx]['id']
                break
        
with open("./data/test_set_fixed.json", "w") as f:
    json.dump(test_data, f, indent=4, ensure_ascii=False)

# %% [markdown]
# # Normalize ND168
# - normalize additional measures
# - format article_section_point
# - split violations ";"

# %%
with open("/home/taidvt/vietnamese-traffic-law-qa/data/processed/ND168_2024.json", "r") as f:
    data_168 = json.load(f)

def normalize_additional_measures(measure):
    try:
        if measure.get('points') == None and measure.get('duration') == None:
            return f"{measure['type']}: {measure['details']}"
        if measure.get('points') and (measure['points'] != "N/A" and measure['points'] != "0"):
            return f"{measure['type']}: {measure['points']} điểm" if "điểm" not in measure['points'].lower() else f"{measure['type']}: {measure['points']}"
        elif measure.get('duration') and (measure['duration'] != "N/A" and measure['duration'] != "0"):
            return f"{measure['type']}: {measure['duration']}"
        else:
            return f"{measure['type']}"
    except Exception as e:
        print(measure)
        raise e
        
def format_article_section_point(article, section, point):
    
    if point and "điểm" not in point.lower():
        point = f"Điểm {point}"
    
    if section and "khoản" not in section.lower():
        section = f"Khoản {section}"
    
    if article and "điều" not in article.lower():
        article = f"Điều {article}"
    return article, section, point

max_len = 1375 + len(data_168['violations'])
print("length of dataset before processing: ", max_len)
for data_idx in range(len(data_168['violations'])):
    # print(data_168['violations'][data_idx]['legal_basis'].keys())
    data_168['violations'][data_idx]['id'] = 1375 + data_idx + 1
    document = "Nghị định 168/2024/NĐ-CP"
    data_168['violations'][data_idx]['legal_basis']['document'] = document
    article = data_168['violations'][data_idx]['legal_basis']['article']
    section = data_168['violations'][data_idx]['legal_basis']['section']
    point = data_168['violations'][data_idx]['legal_basis']['point']
    try:
        article, section, point = format_article_section_point(article, section, point)
    except Exception as e:
        raise e 

    data_168['violations'][data_idx]['legal_basis']['full_reference'] = f"{document}, {article + ', ' if article else ''}{section + ', ' if section else ''}{point if point else ''}"


    data_168['violations'][data_idx]['legal_basis']['article'] = article
    data_168['violations'][data_idx]['legal_basis']['section'] = section
    data_168['violations'][data_idx]['legal_basis']['point'] = point
    if data_168['violations'][data_idx].get('additional_measures') == None:
        data_168['violations'][data_idx]['additional_measures'] = []
    normalized_additional_measures = []
    for measure in data_168['violations'][data_idx]['additional_measures']:
        normalized_additional_measures.append(normalize_additional_measures(measure))
    data_168['violations'][data_idx]['additional_measures'] = normalized_additional_measures
    
    
    if ":" not in data_168['violations'][data_idx]['description'] and len(data_168['violations'][data_idx]['description'].split(";")) > 1:
        try:
            base_violation = data_168['violations'][data_idx]
            first_data = data_168['violations'][data_idx]['description'].split(";")[0]
            remaining_data = data_168['violations'][data_idx]['description'].split(";")[1:]
            data_168['violations'][data_idx]['description'] = first_data.strip()
            for data_idx in range(len(remaining_data)):
                max_len += 1
                data_168['violations'].append({
                    "description": remaining_data[data_idx].strip(),
                    "category": base_violation['category'],
                    "penalty": base_violation['penalty'],
                    "additional_measures": base_violation['additional_measures'],
                    "severity": base_violation['severity'],
                    "legal_basis": base_violation['legal_basis'],
                    "id": max_len
                })
        except Exception as e:
            raise e
            break
    

print("length of dataset after processing: ", max_len)
# Out:
# length of dataset before processing:  2023
# length of dataset after processing:  2182

# %%
len(data_168['violations'])
# Out:
# 807

# %%
with open("/home/taidvt/vietnamese-traffic-law-qa/data/processed/ND168_2024_normalized.json", "w") as f:
    json.dump(data_168, f, indent=4, ensure_ascii=False)

# %% [markdown]
# # Normalize ND100
# - normalize additional measures
# - format article_section_point
# - split violations ";"

# %%
with open("/home/taidvt/vietnamese-traffic-law-qa/data/processed/ND100_2019.json", "r") as f:
    data_100 = json.load(f)

# %%
len(data_100['violations'])
# Out:
# 1165

# %%
def normalize_additional_measures(measure):
    try:
        if measure.get('points') == None and measure.get('duration') == None:
            return f"{measure['type']}: {measure['details']}"
        if measure.get('points') and (measure['points'] != "N/A" and measure['points'] != "0"):
            return f"{measure['type']}: {measure['points']} điểm" if "điểm" not in measure['points'].lower() else f"{measure['type']}: {measure['points']}"
        elif measure.get('duration') and (measure['duration'] != "N/A" and measure['duration'] != "0"):
            return f"{measure['type']}: {measure['duration']}"
        else:
            return f"{measure['type']}"
    except Exception as e:
        print(measure)
        raise e
        
def format_article_section_point(article, section, point):
    
    if point and "điểm" not in point.lower():
        point = f"Điểm {point}"
    
    if section and "khoản" not in section.lower():
        section = f"Khoản {section}"
    
    if article and "điều" not in article.lower():
        article = f"Điều {article}"
    return article, section, point

max_len = len(data_100['violations'])
print("length of dataset before processing: ", max_len)
for data_idx in range(len(data_100['violations'])):
    # print(data_100['violations'][data_idx]['legal_basis'].keys())
    data_100['violations'][data_idx]['id'] = data_idx + 1
    document = "Nghị định 100/2019/NĐ-CP"
    data_100['violations'][data_idx]['legal_basis']['document'] = document
    article = data_100['violations'][data_idx]['legal_basis']['article']
    section = data_100['violations'][data_idx]['legal_basis']['section']
    point = data_100['violations'][data_idx]['legal_basis']['point']
    try:
        article, section, point = format_article_section_point(article, section, point)
    except Exception as e:
        raise e 

    data_100['violations'][data_idx]['legal_basis']['full_reference'] = f"{document}, {article + ', ' if article else ''}{section + ', ' if section else ''}{point if point else ''}"


    data_100['violations'][data_idx]['legal_basis']['article'] = article
    data_100['violations'][data_idx]['legal_basis']['section'] = section
    data_100['violations'][data_idx]['legal_basis']['point'] = point
    if data_100['violations'][data_idx].get('additional_measures') == None:
        data_100['violations'][data_idx]['additional_measures'] = []
    normalized_additional_measures = []
    for measure in data_100['violations'][data_idx]['additional_measures']:
        normalized_additional_measures.append(normalize_additional_measures(measure))
    data_100['violations'][data_idx]['additional_measures'] = normalized_additional_measures
    
    
    if ":" not in data_100['violations'][data_idx]['description'] and len(data_100['violations'][data_idx]['description'].split(";")) > 1:
        try:
            base_violation = data_100['violations'][data_idx]
            first_data = data_100['violations'][data_idx]['description'].split(";")[0]
            remaining_data = data_100['violations'][data_idx]['description'].split(";")[1:]
            data_100['violations'][data_idx]['description'] = first_data.strip()
            for data_idx in range(len(remaining_data)):
                max_len += 1
                data_100['violations'].append({
                    "description": remaining_data[data_idx].strip(),
                    "category": base_violation['category'],
                    "penalty": base_violation['penalty'],
                    "additional_measures": base_violation['additional_measures'],
                    "severity": base_violation['severity'],
                    "legal_basis": base_violation['legal_basis'],
                    "id": max_len
                })
        except Exception as e:
            raise e
            break
    

print("length of dataset after processing: ", max_len)
# Out:
# length of dataset before processing:  1165
# length of dataset after processing:  1375

# %%
with open("/home/taidvt/vietnamese-traffic-law-qa/data/processed/ND100_2019_normalized.json", "w") as f:
    json.dump(data_100, f, indent=4, ensure_ascii=False)
